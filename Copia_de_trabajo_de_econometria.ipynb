# %% [markdown]
# <a href="https://colab.research.google.com/github/majo581/TALLERES/blob/main/Copia_de_trabajo_de_econometria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RELACIÓN ENTRE LOS INTENTOS DE SUICIDIOS Y LOS DELITOS EN COLOMBIA POR MUNICIPIOS EN 2024
# ##  Yuli Fernanda Ezquivel Martinez
# ## María José González serrano

# %% [markdown]
# # 1.Exportacion de datos
# Datos sacados de:
#
#
# *    https://www.policia.gov.co/estadistica-delictiva
# *    https://www.datos.gov.co/Justicia-y-Derecho/Presuntos-Suicidios-Colombia-2015-a-2024-Cifras-de/f75u-mirk/about_data

# %% [markdown]
# SUBIR BASES DE DATOS QUE ESTAN LA CARPETA DATA EN GITHUB

# %%
import pandas as pd

# %%
df_suicidios = pd.read_excel('Presuntos_Suicidios._Colombia,_2015_a_2024._Cifras_definitivas_20260317.xlsx')

df_delitos = pd.read_excel('INFORMACIÓN_DE_DELITOS_A_NIVEL_DE_REGISTRO_AÑO_2024_0.xlsx')

# %% [markdown]
# ##2.Limpiar los datos

# %% [markdown]
# ### 2.1.Filtrar datos del 2024

# %%
df_suicidios_2024 = df_suicidios[df_suicidios['Año del hecho'] == 2024]

print(f"Total de registros originales: {len(df_suicidios)}")
print(f"Registros solo de 2024: {len(df_suicidios_2024)}")

# Ver los primeros registros de 2024
df_suicidios_2024.head()
# Out:
# Total de registros originales: 26558
# Registros solo de 2024: 3014
#          ID  Año del hecho Grupo de Edad Quinquenal   \
# 3945  23567           2024                 (35 a 39)
# 4014  23568           2024                 (55 a 59)
# 4194  23570           2024                 (40 a 44)
# 4329  23571           2024                 (20 a 24)
# 4385  23587           2024                 (35 a 39)
#
#           Grupo Mayor Menor de Edad Grupo de Edad judicial  \
# 3945  b) Mayores de Edad (>18 años)              (35 a 39)
# 4014  b) Mayores de Edad (>18 años)              (55 a 59)
# 4194  b) Mayores de Edad (>18 años)              (40 a 44)
# 4329  b) Mayores de Edad (>18 años)              (20 a 24)
# 4385  b) Mayores de Edad (>18 años)              (35 a 39)
#
#              Ciclo Vital Sexo de la victima Estado Civil País de Nacimiento  \
# 3945   (29 a 59) Adultez             Hombre   Soltero(a)           Colombia
# 4014   (29 a 59) Adultez             Hombre   Soltero(a)           Colombia
# 4194   (29 a 59) Adultez             Hombre   Soltero(a)           Colombia
# 4329  (18 a 28) Juventud             Hombre   Soltero(a)           Colombia
# 4385   (29 a 59) Adultez             Hombre   Soltero(a)           Colombia
#
#                             Escolaridad  ... Manera de Muerte  \
# 3945                    Sin información  ...      2 Suicidios
# 4014  Educación media o secundaria alta  ...      2 Suicidios
# 4194                    Sin información  ...      2 Suicidios
# 4329  Educación media o secundaria alta  ...      2 Suicidios
# 4385                    Sin información  ...      2 Suicidios
#
#      Mecanismo Causal de la Lesión Fatal  \
# 3945                              Tóxico
# 4014              Generadores de asfixia
# 4194                              Tóxico
# 4329              Generadores de asfixia
# 4385                              Tóxico
#
#      Diagnostico Topográfico de la Lesión Fatal Razón del Suicidio  \
# 3945                               Sin lesiones  Enfermedad mental
# 4014                           Trauma de cuello         Económicas
# 4194                               Sin lesiones    Sin información
# 4329                           Trauma de cuello    Sin información
# 4385                            Politraumatismo            Desamor
#
#      Localidad del Hecho  Ancestro Racial Pueblo Indígena  \
# 3945           Chapinero          Mestizo       No aplica
# 4014             Kennedy          Mestizo       No aplica
# 4194             Usaquen          Mestizo       No aplica
# 4329             Kennedy          Mestizo       No aplica
# 4385     Sin información          Mestizo       No aplica
#
#         Orientación Sexual   Identidad de Género           Transgénero
# 3945  No Sabe / No Informa  No Sabe / No Informa  No Sabe / No Informa
# 4014  No Sabe / No Informa             Masculino  No Sabe / No Informa
# 4194  No Sabe / No Informa  No Sabe / No Informa  No Sabe / No Informa
# 4329  No Sabe / No Informa             Masculino  No Sabe / No Informa
# 4385          Heterosexual             Masculino  No Sabe / No Informa
#
# [5 rows x 32 columns]

# %% [markdown]
# ### 2.2.Ver los años únicos en la base (puede haber años que no sean 2024)

# %%
print("Años únicos en la base de suicidios:")
print(df_suicidios['Año del hecho'].value_counts().sort_index())
# Out:
# Años únicos en la base de suicidios:
# Año del hecho
# 2015    2068
# 2016    2310
# 2017    2571
# 2018    2696
# 2019    2643
# 2020    2420
# 2021    2689
# 2022    2952
# 2023    3195
# 2024    3014
# Name: count, dtype: int64

# %% [markdown]
# ### 2.3.Ver si hay fechas que no sean de 2024 a pesar de tener año 2024

# %%
print("Revisando fechas sospechosas en 2024:")
print(df_suicidios[df_suicidios['Año del hecho'] == 2024]['Mes del hecho'].value_counts())
# Out:
# Revisando fechas sospechosas en 2024:
# Mes del hecho
# Enero         285
# Septiembre    279
# Diciembre     267
# Agosto        257
# Noviembre     252
# Julio         252
# Marzo         245
# Octubre       242
# Mayo          240
# Junio         234
# Febrero       231
# Abril         230
# Name: count, dtype: int64

# %% [markdown]
# ### 2.4.Verificar duplicados en la base de suicidios 2024

# %%
duplicados = df_suicidios_2024.duplicated().sum()
print(f"Registros duplicados en Suicidios 2024: {duplicados}")

# Si hay duplicados, mostrarlos
if duplicados > 0:
    print("\nEjemplo de duplicados:")
    print(df_suicidios_2024[df_suicidios_2024.duplicated(keep=False)].head(10))
# Out:
# Registros duplicados en Suicidios 2024: 0

# %% [markdown]
# ### 2.5.Eliminar NaN de la base de delitos

# %%
df_delitos = pd.read_excel('INFORMACIÓN_DE_DELITOS_A_NIVEL_DE_REGISTRO_AÑO_2024_0.xlsx', skiprows=11)

# Limpiar
df_delitos = df_delitos.dropna(subset=['MUNICIPIO', 'DELITOS'], how='all')

palabras_clave = ['TOTAL', 'Fuente', 'Fecha', 'DELITOS OPERACIÓN']
for palabra in palabras_clave:
    mascara = df_delitos['DELITOS'].astype(str).str.contains(palabra, case=False, na=False)
    df_delitos = df_delitos[~mascara]

# Verificar
print(" BASE LIMPIA")
print(f"Registros finales: {len(df_delitos)}")
print("\nÚltimos 5 registros:")
print(df_delitos.tail(5))
# Out:
#  BASE LIMPIA
# Registros finales: 834148
#
# Últimos 5 registros:
#                        ARMAS MEDIOS        DEPARTAMENTO        MUNICIPIO  \
# 834143                ARMA DE FUEGO               HUILA            Suaza
# 834144                ARMA DE FUEGO              TOLIMA          Espinal
# 834145          SIN EMPLEO DE ARMAS                META          Acacías
# 834146  ARMA BLANCA / CORTOPUNZANTE  NORTE DE SANTANDER           Abrego
# 834147                LLAVE MAESTRA           ATLÁNTICO  Puerto Colombia
#
#        FECHA HECHO     GENERO *AGRUPA EDAD PERSONA*  CODIGO DANE  \
# 834143  04/05/2024  MASCULINO               ADULTOS      41770.0
# 834144  16/08/2024  MASCULINO               ADULTOS      73268.0
# 834145  03/10/2024  MASCULINO               ADULTOS      50006.0
# 834146  21/02/2024  MASCULINO               ADULTOS      54003.0
# 834147  13/10/2024  MASCULINO               ADULTOS       8573.0
#
#                                  DELITOS   MES  CANTIDAD
# 834143  ARTÍCULO 239. HURTO MOTOCICLETAS   5.0       1.0
# 834144  ARTÍCULO 239. HURTO MOTOCICLETAS   8.0       1.0
# 834145  ARTÍCULO 239. HURTO MOTOCICLETAS  10.0       1.0
# 834146  ARTÍCULO 239. HURTO MOTOCICLETAS   2.0       1.0
# 834147   ARTÍCULO 239. HURTO AUTOMOTORES  10.0       1.0

# %%
print(f"Registros de SUICIDIOS 2024: {len(df_suicidios_2024)}")
print(f"Registros de DELITOS: {len(df_delitos)}")
# Out:
# Registros de SUICIDIOS 2024: 3014
# Registros de DELITOS: 834148

# %% [markdown]
# ## 3.Agrupar delitos

# %%
# ==========================================
# 1. DEFINIR LA FUNCIÓN DE CLASIFICACIÓN
# ==========================================
def clasificar_delito_final(texto):
    texto = str(texto).upper()

    if 'SECUESTRO' in texto:
        return 'Secuestro'
    elif 'HOMICIDIO' in texto or 'FEMINICIDIO' in texto:
        return 'Homicidios'
    elif 'HURTO' in texto or 'ABIGEATO' in texto:
        return 'Hurto'
    elif ('SEXUAL' in texto or
          'PROSTITUCION' in texto or
          'PROSTITUCIÓN' in texto or
          'PORNOGRAFIA' in texto or
          'PORNOGRAFÍA' in texto or
          'ACCESO CARNAL' in texto or
          'ACTO SEXUAL' in texto or
          'PROXENETISMO' in texto or
          'EXPLOTACION SEXUAL' in texto):
        return 'Delitos Sexuales'
    elif ('LESION' in texto or
          'PERDIDA ANATOMICA' in texto or
          'PÉRDIDA ANATÓMICA' in texto or
          'DEFORMIDAD' in texto or
          'INCAPACIDAD' in texto or
          'PERTURBACION' in texto or
          'PERTURBACIÓN' in texto or
          'VIOLENCIA INTRAFAMILIAR' in texto):
        return 'Lesiones Personales'
    elif ('EXTORSION' in texto or
          'TERRORISMO' in texto or
          'AMENAZAS' in texto or
          'OMISIÓN' in texto or
          'OMISION' in texto):
        return 'Otros Delitos'
    else:
        return 'Otros Delitos'

# ==========================================
# 2. CREAR LA COLUMNA CATEGORIA EN df_delitos (ORIGINAL)
# ==========================================
df_delitos['CATEGORIA'] = df_delitos['DELITOS'].apply(clasificar_delito_final)

print("✅ Columna CATEGORIA creada en df_delitos (DataFrame ORIGINAL)")
print(df_delitos[['DELITOS', 'CATEGORIA']].head(10))

# ==========================================
# 3. VERIFICAR DISTRIBUCIÓN
# ==========================================
print("\n=== DISTRIBUCIÓN DE CATEGORÍAS ===")
print(df_delitos['CATEGORIA'].value_counts())
# Out:
# ✅ Columna CATEGORIA creada en df_delitos (DataFrame ORIGINAL)
#                                              DELITOS   CATEGORIA
# 0  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 1  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 2  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 3  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 4  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 5  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 6  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 7  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 8  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 9  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
#
# === DISTRIBUCIÓN DE CATEGORÍAS ===
# CATEGORIA
# Hurto                  436917
# Lesiones Personales    274321
# Otros Delitos           70510
# Delitos Sexuales        31465
# Homicidios              20622
# Secuestro                 313
# Name: count, dtype: int64

# %%
total_categoria = (df_delitos.groupby('CATEGORIA')['CANTIDAD'].sum().sort_values(ascending=False))
print(total_categoria)
# Out:
# CATEGORIA
# Hurto                  436917.0
# Lesiones Personales    274321.0
# Otros Delitos           70510.0
# Delitos Sexuales        31465.0
# Homicidios              20622.0
# Secuestro                 313.0
# Name: CANTIDAD, dtype: float64

# %% [markdown]
# ##  4.Estadisticas generales de los delitos en los departamentos

# %% [markdown]
# ###  4.1.delitos a nivel nacinal con departamentos

# %%
import matplotlib.pyplot as plt

# Calcular porcentaje a nivel nacional
total_nacional = df_delitos['CANTIDAD'].sum()

porcentaje_categoria = (
    df_delitos
    .groupby('CATEGORIA')['CANTIDAD']
    .sum()
    .sort_values(ascending=False)
)

porcentaje_categoria = (
    porcentaje_categoria / total_nacional
) * 100

# Gráfico
plt.figure(figsize=(10, 6))

bars = plt.bar(
    porcentaje_categoria.index,
    porcentaje_categoria.values,
    color='steelblue',
    edgecolor='black'
)

plt.title(
    'Porcentaje de Delitos por Categoría en Colombia',
    fontsize=14,
    fontweight='bold'
)

plt.xlabel('Categoría', fontsize=12)
plt.ylabel('Porcentaje del Total Nacional (%)', fontsize=12)

plt.xticks(rotation=45, ha='right')

# Valores encima de barras
for bar in bars:

    height = bar.get_height()

    plt.text(
        bar.get_x() + bar.get_width()/2.,
        height + 0.5,
        f'{height:.1f}%',
        ha='center',
        va='bottom',
        fontsize=11,
        fontweight='bold'
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.2.Ver la categoría que más afecta a cada departamento

# %%
# Agrupar por departamento y categoría (usando df_delitos_filtrado)
delitos_por_depto = df_delitos.groupby(['DEPARTAMENTO', 'CATEGORIA'])['CANTIDAD'].sum().reset_index()

# Ver top por departamento
print("TOP 10 DEPARTAMENTOS CON MÁS DELITOS:")
top_deptos = delitos_por_depto.groupby('DEPARTAMENTO')['CANTIDAD'].sum().sort_values(ascending=False).head(10)
print(top_deptos)
# Out:
# TOP 10 DEPARTAMENTOS CON MÁS DELITOS:
# DEPARTAMENTO
# CUNDINAMARCA    301569.0
# ANTIOQUIA       104620.0
# VALLE            81390.0
# SANTANDER        35671.0
# ATLÁNTICO        31000.0
# BOLÍVAR          26663.0
# TOLIMA           25990.0
# NARIÑO           22680.0
# HUILA            22165.0
# META             21849.0
# Name: CANTIDAD, dtype: float64

# %%
categoria_top = delitos_por_depto.loc[
    delitos_por_depto.groupby('DEPARTAMENTO')['CANTIDAD'].idxmax()
]
print("\n CATEGORÍA PRINCIPAL POR DEPARTAMENTO:")
print(categoria_top.sort_values('CANTIDAD', ascending=False).head(10))
# Out:
#  CATEGORÍA PRINCIPAL POR DEPARTAMENTO:
#      DEPARTAMENTO            CATEGORIA  CANTIDAD
# 72   CUNDINAMARCA                Hurto  181921.0
# 7       ANTIOQUIA                Hurto   56840.0
# 171         VALLE                Hurto   41852.0
# 154     SANTANDER                Hurto   16267.0
# 19      ATLÁNTICO                Hurto   15589.0
# 101         HUILA                Hurto   12067.0
# 25        BOLÍVAR                Hurto   11817.0
# 119        NARIÑO                Hurto   11617.0
# 113          META                Hurto   11146.0
# 166        TOLIMA  Lesiones Personales   11026.0

# %% [markdown]
# ###  4.3.Total de delitos por categoria

# %%
import matplotlib.pyplot as plt

# Configurar estilo
plt.style.use('default')

# Gráfico de barras
categorias_total = df_delitos.groupby('CATEGORIA')['CANTIDAD'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
categorias_total.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Total de Delitos por Categoría (Colombia)', fontsize=14)
plt.xlabel('Categoría', fontsize=12)
plt.ylabel('Cantidad de Delitos', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  4.4.Top 5 departamentos por tipo de delito

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.flatten()

for i, categoria in enumerate(df_delitos['CATEGORIA'].unique()):
    datos = df_delitos[df_delitos['CATEGORIA'] == categoria]
    top = datos.groupby('DEPARTAMENTO')['CANTIDAD'].sum().sort_values(ascending=False).head(5)

    top.plot(kind='bar', ax=axes[i], color='coral', edgecolor='black')
    axes[i].set_title(f'{categoria}', fontsize=12)
    axes[i].set_xlabel('Departamento')
    axes[i].set_ylabel('Cantidad')
    axes[i].tick_params(axis='x', rotation=45)

# Ocultar el último subplot si sobra
if len(df_delitos['CATEGORIA'].unique()) < 6:
    axes[-1].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.5.Top 15 departamentos com mas delitos en mapa de calor

# %%
import seaborn as sns
import matplotlib.pyplot as plt

matriz_delitos = df_delitos.pivot_table(
    values='CANTIDAD',
    index='DEPARTAMENTO',
    columns='CATEGORIA',
    aggfunc='sum',
    fill_value=0
)

top_deptos = matriz_delitos.sum(axis=1).sort_values(ascending=False).head(15).index
matriz_top = matriz_delitos.loc[top_deptos]

plt.figure(figsize=(12, 8))
sns.heatmap(matriz_top, annot=True, fmt='.0f', cmap='YlOrRd', linewidths=0.5)
plt.title('Distribución de Delitos por Departamento y Categoría', fontsize=14)
plt.xlabel('Categoría')
plt.ylabel('Departamento')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##  5.Estadisticas generales por municipios

# %% [markdown]
# ###  5.1.Comparar municipios de ambas bases

# %%
print("="*60)
print("MUNICIPIOS EN BASE DE SUICIDIOS 2024")
print("="*60)

municipios_sui = sorted(df_suicidios_2024['Municipio del hecho DANE'].unique())
print(f"Total: {len(municipios_sui)} municipios\n")

for i, mun in enumerate(municipios_sui, 1):
    print(f"{i}. {mun}")
# Out:
# ============================================================
# MUNICIPIOS EN BASE DE SUICIDIOS 2024
# ============================================================
# Total: 611 municipios
#
# 1. Abejorral
# 2. Acacías
# 3. Acandí
# 4. Acevedo
# 5. Agrado
# 6. Agua de Dios
# 7. Aguachica
# 8. Aguadas
# 9. Agustín Codazzi
# 10. Aipe
# 11. Albania
# 12. Albán
# 13. Alcalá
# 14. Algeciras
# 15. Almaguer
# 16. Alvarado
# 17. Amalfi
# 18. Ambalema
# 19. Anapoima
# 20. Andalucía
# 21. Andes
# 22. Angelópolis
# 23. Anolaima
# 24. Anorí
# 25. Anserma
# 26. Anzoátegui
# 27. Anzá
# 28. Apartadó
# 29. Apía
# 30. Aquitania
# 31. Aranzazu
# 32. Aratoca
# 33. Arauca
# 34. Arauquita
# 35. Arboleda
# 36. Arcabuco
# 37. Argelia
# 38. Ariguaní
# 39. Arjona
# 40. Armenia
# 41. Armero Guayabal
# 42. Astrea
# 43. Ataco
# 44. Atrato
# 45. Ayapel
# 46. Balboa
# 47. Barbacoas
# 48. Barbosa
# 49. Barrancabermeja
# 50. Barrancas
# 51. Barranquilla
# 52. Becerril
# 53. Belalcázar
# 54. Bello
# 55. Belmira
# 56. Belén de Bajirá
# 57. Belén de Umbría
# 58. Betania
# 59. Bochalema
# 60. Bogotá, D.C.
# 61. Bojacá
# 62. Bojayá
# 63. Bolívar
# 64. Bosconia
# 65. Boyacá
# 66. Bucaramanga
# 67. Bucarasica
# 68. Buenaventura
# 69. Buenavista
# 70. Buesaco
# 71. Bugalagrande
# 72. Busbanzá
# 73. Cachipay
# 74. Caicedo
# 75. Caicedonia
# 76. Cajamarca
# 77. Cajibío
# 78. Cajicá
# 79. Calamar
# 80. Calarcá
# 81. Caldas
# 82. Caldono
# 83. Cali
# 84. Calima
# 85. Caloto
# 86. Campamento
# 87. Campoalegre
# 88. Canalete
# 89. Candelaria
# 90. Capitanejo
# 91. Carepa
# 92. Carmen de Apicalá
# 93. Carmen de Carupa
# 94. Carmen del Darién
# 95. Carolina
# 96. Cartagena de Indias
# 97. Cartagena del Chairá
# 98. Cartago
# 99. Casabianca
# 100. Castilla la Nueva
# 101. Caucasia
# 102. Cañasgordas
# 103. Cereté
# 104. Cerinza
# 105. Chachagüí
# 106. Chaguaní
# 107. Chaparral
# 108. Chigorodó
# 109. Chima
# 110. Chimichagua
# 111. Chinchiná
# 112. Chinácota
# 113. Chinú
# 114. Chiquinquirá
# 115. Chiriguaná
# 116. Chiscas
# 117. Chitagá
# 118. Chocontá
# 119. Chía
# 120. Cimitarra
# 121. Ciudad Bolívar
# 122. Ciénaga
# 123. Ciénaga de Oro
# 124. Ciénega
# 125. Clemencia
# 126. Cocorná
# 127. Colombia
# 128. Coloso
# 129. Colón
# 130. Concepción
# 131. Concordia
# 132. Consacá
# 133. Contadero
# 134. Convención
# 135. Copacabana
# 136. Corinto
# 137. Corozal
# 138. Cota
# 139. Coveñas
# 140. Cucunubá
# 141. Cucutilla
# 142. Cumaral
# 143. Cumbal
# 144. Cumbitara
# 145. Curillo
# 146. Curití
# 147. Cuítiva
# 148. Cáchira
# 149. Cáqueza
# 150. Cómbita
# 151. Córdoba
# 152. Cúcuta
# 153. Dabeiba
# 154. Dagua
# 155. Dibulla
# 156. Distracción
# 157. Donmatías
# 158. Dosquebradas
# 159. Duitama
# 160. El Bagre
# 161. El Cairo
# 162. El Carmen
# 163. El Carmen de Bolívar
# 164. El Carmen de Chucurí
# 165. El Carmen de Viboral
# 166. El Cerrito
# 167. El Charco
# 168. El Colegio
# 169. El Doncello
# 170. El Dorado
# 171. El Dovio
# 172. El Paso
# 173. El Peñón
# 174. El Playón
# 175. El Retén
# 176. El Roble
# 177. El Rosal
# 178. El Santuario
# 179. El Tambo
# 180. El Tarra
# 181. El Zulia
# 182. Envigado
# 183. Espinal
# 184. Facatativá
# 185. Filadelfia
# 186. Flandes
# 187. Florencia
# 188. Florida
# 189. Floridablanca
# 190. Fonseca
# 191. Fortul
# 192. Fresno
# 193. Frontino
# 194. Fuente de Oro
# 195. Fundación
# 196. Funes
# 197. Funza
# 198. Fusagasugá
# 199. Fómeque
# 200. Gachancipá
# 201. Gachantivá
# 202. Galapa
# 203. Galeras
# 204. Galán
# 205. Garagoa
# 206. Garzón
# 207. Gigante
# 208. Ginebra
# 209. Girardot
# 210. Girardota
# 211. Girón
# 212. Granada
# 213. Guacarí
# 214. Guachené
# 215. Guachetá
# 216. Guachucal
# 217. Guadalajara de Buga
# 218. Guaduas
# 219. Guamal
# 220. Guamo
# 221. Guapotá
# 222. Guarne
# 223. Guasca
# 224. Guateque
# 225. Guayabetal
# 226. Guática
# 227. Gámbita
# 228. Génova
# 229. Gómez Plata
# 230. Güicán
# 231. Hacarí
# 232. Hatonuevo
# 233. Herveo
# 234. Hispania
# 235. Ibagué
# 236. Inzá
# 237. Inírida
# 238. Ipiales
# 239. Isnos
# 240. Istmina
# 241. Itagüí
# 242. Ituango
# 243. Jamundí
# 244. Jardín
# 245. Jericó
# 246. Jesús María
# 247. La Apartada
# 248. La Argentina
# 249. La Calera
# 250. La Ceja
# 251. La Cruz
# 252. La Cumbre
# 253. La Dorada
# 254. La Esperanza
# 255. La Estrella
# 256. La Florida
# 257. La Gloria
# 258. La Jagua de Ibirico
# 259. La Jagua del Pilar
# 260. La Llanada
# 261. La Merced
# 262. La Mesa
# 263. La Palma
# 264. La Pintada
# 265. La Plata
# 266. La Primavera
# 267. La Salina
# 268. La Sierra
# 269. La Tebaida
# 270. La Unión
# 271. La Vega
# 272. La Victoria
# 273. Labateca
# 274. Landázuri
# 275. Lebrija
# 276. Leiva
# 277. Lenguazaque
# 278. Leticia
# 279. Liborina
# 280. Lorica
# 281. Los Córdobas
# 282. Los Patios
# 283. Lourdes
# 284. Luruaco
# 285. Lérida
# 286. Líbano
# 287. Maceo
# 288. Madrid
# 289. Magangué
# 290. Mahates
# 291. Maicao
# 292. Majagual
# 293. Malambo
# 294. Mallama
# 295. Manatí
# 296. Manaure Balcón del Cesar
# 297. Manizales
# 298. Manzanares
# 299. Maní
# 300. Marinilla
# 301. Marmato
# 302. Marsella
# 303. María la Baja
# 304. Matanza
# 305. Medellín
# 306. Medio Baudó
# 307. Melgar
# 308. Mesetas
# 309. Miranda
# 310. Mistrató
# 311. Mitú
# 312. Mocoa
# 313. Mogotes
# 314. Momil
# 315. Mompós
# 316. Moniquirá
# 317. Montebello
# 318. Montelíbano
# 319. Montenegro
# 320. Monterrey
# 321. Montería
# 322. Morales
# 323. Morroa
# 324. Mosquera
# 325. Moñitos
# 326. Mutatá
# 327. Mutiscua
# 328. Málaga
# 329. Necoclí
# 330. Neira
# 331. Neiva
# 332. Nemocón
# 333. Nilo
# 334. Nunchía
# 335. Ocaña
# 336. Olaya
# 337. Olaya Herrera
# 338. Orito
# 339. Orocué
# 340. Ovejas
# 341. Paicol
# 342. Pailitas
# 343. Paime
# 344. Paipa
# 345. Palermo
# 346. Palestina
# 347. Palmar de Varela
# 348. Palmira
# 349. Palmito
# 350. Palocabildo
# 351. Pamplona
# 352. Paratebueno
# 353. Pasca
# 354. Pasto
# 355. Patía
# 356. Paz de Ariporo
# 357. Pelaya
# 358. Pensilvania
# 359. Pereira
# 360. Peñol
# 361. Piedecuesta
# 362. Piedras
# 363. Piendamó
# 364. Pijao
# 365. Pijiño del Carmen
# 366. Pital
# 367. Pitalito
# 368. Pivijay
# 369. Planadas
# 370. Planeta Rica
# 371. Policarpa
# 372. Polonuevo
# 373. Ponedera
# 374. Popayán
# 375. Pore
# 376. Pradera
# 377. Prado
# 378. Providencia
# 379. Pueblo Nuevo
# 380. Pueblo Rico
# 381. Puebloviejo
# 382. Puente Nacional
# 383. Puerres
# 384. Puerto Asís
# 385. Puerto Berrío
# 386. Puerto Boyacá
# 387. Puerto Caicedo
# 388. Puerto Carreño
# 389. Puerto Colombia
# 390. Puerto Concordia
# 391. Puerto Escondido
# 392. Puerto Gaitán
# 393. Puerto Guzmán
# 394. Puerto Leguízamo
# 395. Puerto Libertador
# 396. Puerto Lleras
# 397. Puerto López
# 398. Puerto Rico
# 399. Puerto Tejada
# 400. Puerto Wilches
# 401. Pupiales
# 402. Puracé
# 403. Pácora
# 404. Quibdó
# 405. Quimbaya
# 406. Quinchía
# 407. Quipile
# 408. Ramiriquí
# 409. Remedios
# 410. Remolino
# 411. Repelón
# 412. Restrepo
# 413. Retiro
# 414. Ricaurte
# 415. Rioblanco
# 416. Riohacha
# 417. Rionegro
# 418. Riosucio
# 419. Rivera
# 420. Roberto Payán
# 421. Roldanillo
# 422. Rovira
# 423. Río de Oro
# 424. Sabana de Torres
# 425. Sabanagrande
# 426. Sabanalarga
# 427. Sabaneta
# 428. Saboyá
# 429. Sahagún
# 430. Saladoblanco
# 431. Salamina
# 432. Samacá
# 433. Samaniego
# 434. Samaná
# 435. Sampués
# 436. San Agustín
# 437. San Andrés
# 438. San Andrés de Sotavento
# 439. San Andrés de Tumaco
# 440. San Antero
# 441. San Benito Abad
# 442. San Bernardo del Viento
# 443. San Calixto
# 444. San Carlos
# 445. San Carlos de Guaroa
# 446. San Cayetano
# 447. San Estanislao
# 448. San Francisco
# 449. San Gil
# 450. San Jacinto
# 451. San José de la Montaña
# 452. San José del Fragua
# 453. San José del Guaviare
# 454. San Juan Nepomuceno
# 455. San Juan de Arama
# 456. San Juan de Rioseco
# 457. San Juan del Cesar
# 458. San Luis
# 459. San Luis de Cubarral
# 460. San Luis de Gaceno
# 461. San Luis de Sincé
# 462. San Marcos
# 463. San Martín
# 464. San Miguel
# 465. San Onofre
# 466. San Pablo
# 467. San Pedro
# 468. San Pedro de Cartago
# 469. San Pedro de Urabá
# 470. San Pedro de los Milagros
# 471. San Pelayo
# 472. San Roque
# 473. San Sebastián de Mariquita
# 474. San Vicente Ferrer
# 475. San Vicente de Chucurí
# 476. San Vicente del Caguán
# 477. Sandoná
# 478. Santa Fé de Antioquia
# 479. Santa Isabel
# 480. Santa Marta
# 481. Santa María
# 482. Santa Rosa
# 483. Santa Rosa de Cabal
# 484. Santa Rosa de Osos
# 485. Santa Rosa de Viterbo
# 486. Santa Rosa del Sur
# 487. Santander de Quilichao
# 488. Santiago
# 489. Santiago de Tolú
# 490. Santo Domingo
# 491. Santo Tomás
# 492. Santuario
# 493. Saravena
# 494. Sardinata
# 495. Sasaima
# 496. Sativasur
# 497. Segovia
# 498. Sevilla
# 499. Siachoque
# 500. Sibaté
# 501. Sibundoy
# 502. Silvania
# 503. Silvia
# 504. Simacota
# 505. Simijaca
# 506. Simití
# 507. Sin información
# 508. Sincelejo
# 509. Sitionuevo
# 510. Soacha
# 511. Socha
# 512. Socorro
# 513. Socotá
# 514. Sogamoso
# 515. Solano
# 516. Soledad
# 517. Sonsón
# 518. Sopetrán
# 519. Soplaviento
# 520. Sopó
# 521. Soracá
# 522. Suaita
# 523. Suaza
# 524. Subachoque
# 525. Suesca
# 526. Supía
# 527. Susa
# 528. Susacón
# 529. Sutatausa
# 530. Suárez
# 531. Tabio
# 532. Tadó
# 533. Talaigua Nuevo
# 534. Tame
# 535. Taminango
# 536. Tarqui
# 537. Tauramena
# 538. Tausa
# 539. Tello
# 540. Tenza
# 541. Teorama
# 542. Tibasosa
# 543. Tibú
# 544. Tierralta
# 545. Timaná
# 546. Timbío
# 547. Tipacoque
# 548. Toca
# 549. Tocancipá
# 550. Tolú Viejo
# 551. Tona
# 552. Toribío
# 553. Totoró
# 554. Trinidad
# 555. Trujillo
# 556. Tuluá
# 557. Tunja
# 558. Turbaco
# 559. Turbo
# 560. Tuta
# 561. Támara
# 562. Tópaga
# 563. Túquerres
# 564. Ubalá
# 565. Unión Panamericana
# 566. Uribe
# 567. Urrao
# 568. Urumita
# 569. Usiacurí
# 570. Valdivia
# 571. Valencia
# 572. Valle del Guamuez
# 573. Valledupar
# 574. Vegachí
# 575. Venadillo
# 576. Vergara
# 577. Vianí
# 578. Victoria
# 579. Vigía del Fuerte
# 580. Villa Rica
# 581. Villa de Leyva
# 582. Villa de San Diego de Ubaté
# 583. Villa del Rosario
# 584. Villagarzón
# 585. Villahermosa
# 586. Villamaría
# 587. Villanueva
# 588. Villarrica
# 589. Villavicencio
# 590. Villavieja
# 591. Villeta
# 592. Viotá
# 593. Vistahermosa
# 594. Viterbo
# 595. Vélez
# 596. Yacopí
# 597. Yaguará
# 598. Yarumal
# 599. Yolombó
# 600. Yondó
# 601. Yopal
# 602. Yotoco
# 603. Yumbo
# 604. Zapatoca
# 605. Zaragoza
# 606. Zarzal
# 607. Zetaquira
# 608. Zipacón
# 609. Zipaquirá
# 610. Zona Bananera
# 611. Ábrego

# %%
print("="*60)
print(" MUNICIPIOS EN BASE DE DELITOS")
print("="*60)

# Eliminar NaN y convertir a string
municipios_del = sorted([str(m) for m in df_delitos['MUNICIPIO'].unique() if pd.notna(m)])
print(f"Total: {len(municipios_del)} municipios\n")

for i, mun in enumerate(municipios_del, 1):
    print(f"{i}. {mun}")
# Out:
# ============================================================
#  MUNICIPIOS EN BASE DE DELITOS
# ============================================================
# Total: 1021 municipios
#
# 1. Abejorral
# 2. Abrego
# 3. Abriaquí
# 4. Acacías
# 5. Acandí
# 6. Acevedo
# 7. Achí
# 8. Agrado
# 9. Agua de Dios
# 10. Aguachica
# 11. Aguada
# 12. Aguadas
# 13. Aguazul
# 14. Agustín Codazzi
# 15. Aipe
# 16. Albania
# 17. Albán
# 18. Alcalá
# 19. Aldana
# 20. Alejandría
# 21. Algarrobo
# 22. Algeciras
# 23. Almaguer
# 24. Almeida
# 25. Alpujarra
# 26. Altamira
# 27. Alto Baudó
# 28. Altos del Rosario
# 29. Alvarado
# 30. Amagá
# 31. Amalfi
# 32. Ambalema
# 33. Anapoima
# 34. Ancuyá
# 35. Andalucía
# 36. Andes
# 37. Angelópolis
# 38. Angostura
# 39. Anolaima
# 40. Anorí
# 41. Anserma
# 42. Ansermanuevo
# 43. Anza
# 44. Anzoátegui
# 45. Apartadó
# 46. Apulo
# 47. Apía
# 48. Aquitania
# 49. Aracataca
# 50. Aranzazu
# 51. Aratoca
# 52. Arauca (CT)
# 53. Arauquita
# 54. Arbeláez
# 55. Arboleda
# 56. Arboledas
# 57. Arboletes
# 58. Arcabuco
# 59. Arenal
# 60. Argelia
# 61. Ariguaní
# 62. Arjona
# 63. Armenia
# 64. Armenia (CT)
# 65. Armero
# 66. Arroyohondo
# 67. Astrea
# 68. Ataco
# 69. Atrato
# 70. Ayapel
# 71. Bagadó
# 72. Bahía Solano
# 73. Bajo Baudó
# 74. Balboa
# 75. Baranoa
# 76. Baraya
# 77. Barbacoas
# 78. Barbosa
# 79. Barichara
# 80. Barranca de Upía
# 81. Barrancabermeja
# 82. Barrancas
# 83. Barranco de Loba
# 84. Barranquilla (CT)
# 85. Becerril
# 86. Belalcázar
# 87. Bello
# 88. Belmira
# 89. Beltrán
# 90. Belén
# 91. Belén de Los Andaquies
# 92. Belén de Umbría
# 93. Berbeo
# 94. Betania
# 95. Betulia
# 96. Betéitiva
# 97. Bituima
# 98. Boavita
# 99. Bochalema
# 100. Bogotá D.C. (CT)
# 101. Bojacá
# 102. Bojayá
# 103. Bolívar
# 104. Bosconia
# 105. Boyacá
# 106. Briceño
# 107. Bucaramanga (CT)
# 108. Bucarasica
# 109. Buenaventura
# 110. Buenavista
# 111. Buenos Aires
# 112. Buesaco
# 113. Bugalagrande
# 114. Buriticá
# 115. Busbanzá
# 116. Cabrera
# 117. Cabuyaro
# 118. Cachipay
# 119. Cachirá
# 120. Caicedo
# 121. Caicedonia
# 122. Caimito
# 123. Cajamarca
# 124. Cajibío
# 125. Cajicá
# 126. Calamar
# 127. Calarca
# 128. Caldas
# 129. Caldono
# 130. Cali (CT)
# 131. California
# 132. Calima
# 133. Caloto
# 134. Campamento
# 135. Campo de La Cruz
# 136. Campoalegre
# 137. Campohermoso
# 138. Canalete
# 139. Candelaria
# 140. Cantagallo
# 141. Caparrapí
# 142. Capitanejo
# 143. Caqueza
# 144. Caracolí
# 145. Caramanta
# 146. Carcasí
# 147. Carepa
# 148. Carmen de Apicalá
# 149. Carmen de Carupa
# 150. Carmen del Darien
# 151. Carolina
# 152. Cartagena (CT)
# 153. Cartagena del Chairá
# 154. Cartago
# 155. Caruru
# 156. Casabianca
# 157. Castilla la Nueva
# 158. Caucasia
# 159. Cañasgordas
# 160. Cepitá
# 161. Cereté
# 162. Cerinza
# 163. Cerrito
# 164. Cerro San Antonio
# 165. Chachagüí
# 166. Chaguaní
# 167. Chalán
# 168. Chameza
# 169. Chaparral
# 170. Charalá
# 171. Charta
# 172. Chigorodó
# 173. Chima
# 174. Chimichagua
# 175. Chimá
# 176. Chinavita
# 177. Chinchiná
# 178. Chinácota
# 179. Chinú
# 180. Chipaque
# 181. Chipatá
# 182. Chiquinquirá
# 183. Chiriguaná
# 184. Chiscas
# 185. Chita
# 186. Chitagá
# 187. Chitaraque
# 188. Chivatá
# 189. Chivolo
# 190. Chivor
# 191. Choachí
# 192. Chocontá
# 193. Chía
# 194. Chíquiza
# 195. Cicuco
# 196. Cimitarra
# 197. Circasia
# 198. Cisneros
# 199. Ciudad Bolívar
# 200. Ciénaga
# 201. Ciénaga de Oro
# 202. Ciénega
# 203. Clemencia
# 204. Cocorná
# 205. Coello
# 206. Cogua
# 207. Colombia
# 208. Coloso
# 209. Colón
# 210. Concepción
# 211. Concordia
# 212. Condoto
# 213. Confines
# 214. Consaca
# 215. Contadero
# 216. Contratación
# 217. Convención
# 218. Copacabana
# 219. Coper
# 220. Corinto
# 221. Coromoro
# 222. Corozal
# 223. Corrales
# 224. Cota
# 225. Cotorra
# 226. Covarachía
# 227. Coveñas
# 228. Coyaima
# 229. Cravo Norte
# 230. Cuaspud
# 231. Cubarral
# 232. Cubará
# 233. Cucaita
# 234. Cucunubá
# 235. Cucutilla
# 236. Cumaral
# 237. Cumaribo
# 238. Cumbal
# 239. Cumbitara
# 240. Cunday
# 241. Curillo
# 242. Curití
# 243. Curumaní
# 244. Cuítiva
# 245. Cáceres
# 246. Cácota
# 247. Cértegui
# 248. Cómbita
# 249. Córdoba
# 250. Cúcuta (CT)
# 251. Dabeiba
# 252. Dagua
# 253. Dibulla
# 254. Distracción
# 255. Dolores
# 256. Don Matías
# 257. Dosquebradas
# 258. Duitama
# 259. Durania
# 260. Ebéjico
# 261. El Bagre
# 262. El Banco
# 263. El Cairo
# 264. El Calvario
# 265. El Cantón del San Pablo
# 266. El Carmen
# 267. El Carmen de Atrato
# 268. El Carmen de Bolívar
# 269. El Carmen de Chucurí
# 270. El Carmen de Viboral
# 271. El Castillo
# 272. El Cerrito
# 273. El Charco
# 274. El Cocuy
# 275. El Colegio
# 276. El Copey
# 277. El Doncello
# 278. El Dorado
# 279. El Dovio
# 280. El Espino
# 281. El Guacamayo
# 282. El Guamo
# 283. El Litoral del San Juan
# 284. El Molino
# 285. El Paso
# 286. El Paujil
# 287. El Peñol
# 288. El Peñón
# 289. El Piñon
# 290. El Playón
# 291. El Retorno
# 292. El Retén
# 293. El Roble
# 294. El Rosal
# 295. El Rosario
# 296. El Santuario
# 297. El Tablón de Gómez
# 298. El Tambo
# 299. El Tarra
# 300. El Zulia
# 301. El Águila
# 302. Elías
# 303. Encino
# 304. Enciso
# 305. Entrerrios
# 306. Envigado
# 307. Espinal
# 308. Facatativá
# 309. Falan
# 310. Filadelfia
# 311. Filandia
# 312. Firavitoba
# 313. Flandes
# 314. Florencia
# 315. Florencia (CT)
# 316. Floresta
# 317. Florida
# 318. Floridablanca
# 319. Florián
# 320. Fomeque
# 321. Fonseca
# 322. Fortul
# 323. Fosca
# 324. Francisco Pizarro
# 325. Fredonia
# 326. Fresno
# 327. Frontino
# 328. Fuente de Oro
# 329. Fundación
# 330. Funes
# 331. Funza
# 332. Fusagasugá
# 333. Fúquene
# 334. Gachala
# 335. Gachancipá
# 336. Gachantivá
# 337. Gachetá
# 338. Galapa
# 339. Galeras
# 340. Galán
# 341. Gama
# 342. Gamarra
# 343. Gambita
# 344. Gameza
# 345. Garagoa
# 346. Garzón
# 347. Gigante
# 348. Ginebra
# 349. Giraldo
# 350. Girardot
# 351. Girardota
# 352. Girón
# 353. González
# 354. Gramalote
# 355. Granada
# 356. Guaca
# 357. Guacamayas
# 358. Guacarí
# 359. Guachené
# 360. Guachetá
# 361. Guachucal
# 362. Guadalajara de Buga
# 363. Guadalupe
# 364. Guaduas
# 365. Guaitarilla
# 366. Gualmatán
# 367. Guamal
# 368. Guamo
# 369. Guapi
# 370. Guapotá
# 371. Guaranda
# 372. Guarne
# 373. Guasca
# 374. Guatapé
# 375. Guataquí
# 376. Guatavita
# 377. Guateque
# 378. Guavatá
# 379. Guayabal de Siquima
# 380. Guayabetal
# 381. Guayatá
# 382. Gutiérrez
# 383. Guática
# 384. Génova
# 385. Gómez Plata
# 386. Güepsa
# 387. Güicán
# 388. Hacarí
# 389. Hatillo de Loba
# 390. Hato
# 391. Hato Corozal
# 392. Hatonuevo
# 393. Heliconia
# 394. Herrán
# 395. Herveo
# 396. Hispania
# 397. Hobo
# 398. Honda
# 399. Ibagué (CT)
# 400. Icononzo
# 401. Iles
# 402. Imués
# 403. Inzá
# 404. Inírida (CT)
# 405. Ipiales
# 406. Iquira
# 407. Isnos
# 408. Istmina
# 409. Itagui
# 410. Ituango
# 411. Iza
# 412. Jambaló
# 413. Jamundí
# 414. Jardín
# 415. Jenesano
# 416. Jericó
# 417. Jerusalén
# 418. Jesús María
# 419. Juan de Acosta
# 420. Junín
# 421. Juradó
# 422. La Apartada
# 423. La Argentina
# 424. La Belleza
# 425. La Calera
# 426. La Capilla
# 427. La Ceja
# 428. La Celia
# 429. La Cruz
# 430. La Cumbre
# 431. La Dorada
# 432. La Esperanza
# 433. La Estrella
# 434. La Florida
# 435. La Gloria
# 436. La Jagua de Ibirico
# 437. La Jagua del Pilar
# 438. La Llanada
# 439. La Macarena
# 440. La Merced
# 441. La Mesa
# 442. La Montañita
# 443. La Palma
# 444. La Paz
# 445. La Peña
# 446. La Pintada
# 447. La Plata
# 448. La Playa
# 449. La Primavera
# 450. La Salina
# 451. La Sierra
# 452. La Tebaida
# 453. La Tola
# 454. La Unión
# 455. La Uvita
# 456. La Vega
# 457. La Victoria
# 458. La Virginia
# 459. Labateca
# 460. Labranzagrande
# 461. Landázuri
# 462. Lebrija
# 463. Leiva
# 464. Lejanías
# 465. Lenguazaque
# 466. Leticia (CT)
# 467. Liborina
# 468. Linares
# 469. Lloró
# 470. Lorica
# 471. Los Andes
# 472. Los Córdobas
# 473. Los Palmitos
# 474. Los Patios
# 475. Los Santos
# 476. Lourdes
# 477. Luruaco
# 478. Lérida
# 479. Líbano
# 480. López
# 481. Macanal
# 482. Macaravita
# 483. Maceo
# 484. Macheta
# 485. Madrid
# 486. Magangué
# 487. Magüi
# 488. Mahates
# 489. Maicao
# 490. Majagual
# 491. Malambo
# 492. Mallama
# 493. Manatí
# 494. Manaure
# 495. Manizales (CT)
# 496. Manta
# 497. Manzanares
# 498. Maní
# 499. Mapiripán
# 500. Margarita
# 501. Marinilla
# 502. Maripí
# 503. Mariquita
# 504. Marmato
# 505. Marquetalia
# 506. Marsella
# 507. Marulanda
# 508. María La Baja
# 509. Matanza
# 510. Medellín (CT)
# 511. Medina
# 512. Medio Atrato
# 513. Medio Baudó
# 514. Medio San Juan
# 515. Melgar
# 516. Mercaderes
# 517. Mesetas
# 518. Milán
# 519. Miraflores
# 520. Miranda
# 521. Mistrató
# 522. Mitú (CT)
# 523. Mocoa (CT)
# 524. Mogotes
# 525. Molagavita
# 526. Momil
# 527. Mompós
# 528. Mongua
# 529. Monguí
# 530. Moniquirá
# 531. Montebello
# 532. Montecristo
# 533. Montelíbano
# 534. Montenegro
# 535. Monterrey
# 536. Montería (CT)
# 537. Morales
# 538. Morelia
# 539. Morroa
# 540. Mosquera
# 541. Motavita
# 542. Moñitos
# 543. Murillo
# 544. Murindó
# 545. Mutatá
# 546. Mutiscua
# 547. Muzo
# 548. Málaga
# 549. Nariño
# 550. Natagaima
# 551. Nechí
# 552. Necoclí
# 553. Neira
# 554. Neiva (CT)
# 555. Nemocón
# 556. Nilo
# 557. Nimaima
# 558. Nobsa
# 559. Nocaima
# 560. Norcasia
# 561. Norosí
# 562. Nueva Granada
# 563. Nuevo Colón
# 564. Nunchía
# 565. Nuquí
# 566. Nátaga
# 567. Nóvita
# 568. Obando
# 569. Ocamonte
# 570. Ocaña
# 571. Oiba
# 572. Oicatá
# 573. Olaya
# 574. Olaya Herrera
# 575. Onzaga
# 576. Oporapa
# 577. Orito
# 578. Orocué
# 579. Ortega
# 580. Ospina
# 581. Otanche
# 582. Ovejas
# 583. Pachavita
# 584. Pacho
# 585. Padilla
# 586. Paez
# 587. Paicol
# 588. Pailitas
# 589. Paime
# 590. Paipa
# 591. Pajarito
# 592. Palermo
# 593. Palestina
# 594. Palmar
# 595. Palmar de Varela
# 596. Palmas del Socorro
# 597. Palmira
# 598. Palmito
# 599. Palocabildo
# 600. Pamplona
# 601. Pamplonita
# 602. Pandi
# 603. Panqueba
# 604. Paratebueno
# 605. Pasca
# 606. Pasto (CT)
# 607. Patía
# 608. Pauna
# 609. Paya
# 610. Paz de Ariporo
# 611. Paz de Río
# 612. Pedraza
# 613. Pelaya
# 614. Pensilvania
# 615. Peque
# 616. Pereira (CT)
# 617. Pesca
# 618. Peñol
# 619. Piamonte
# 620. Piedecuesta
# 621. Piedras
# 622. Piendamó
# 623. Pijao
# 624. Pijiño del Carmen
# 625. Pinchote
# 626. Pinillos
# 627. Piojó
# 628. Pisba
# 629. Pital
# 630. Pitalito
# 631. Pivijay
# 632. Planadas
# 633. Planeta Rica
# 634. Plato
# 635. Policarpa
# 636. Polonuevo
# 637. Ponedera
# 638. Popayán (CT)
# 639. Pore
# 640. Potosí
# 641. Pradera
# 642. Prado
# 643. Providencia
# 644. Pueblo Bello
# 645. Pueblo Nuevo
# 646. Pueblo Rico
# 647. Pueblorrico
# 648. Puebloviejo
# 649. Puente Nacional
# 650. Puerres
# 651. Puerto Asís
# 652. Puerto Berrío
# 653. Puerto Boyacá
# 654. Puerto Caicedo
# 655. Puerto Carreño (CT)
# 656. Puerto Colombia
# 657. Puerto Concordia
# 658. Puerto Escondido
# 659. Puerto Gaitán
# 660. Puerto Guzmán
# 661. Puerto Leguízamo
# 662. Puerto Libertador
# 663. Puerto Lleras
# 664. Puerto López
# 665. Puerto Nare
# 666. Puerto Nariño
# 667. Puerto Parra
# 668. Puerto Rico
# 669. Puerto Rondón
# 670. Puerto Salgar
# 671. Puerto Santander
# 672. Puerto Tejada
# 673. Puerto Triunfo
# 674. Puerto Wilches
# 675. Pulí
# 676. Pupiales
# 677. Puracé
# 678. Purificación
# 679. Purísima
# 680. Pácora
# 681. Páez
# 682. Páramo
# 683. Quebradanegra
# 684. Quetame
# 685. Quibdó (CT)
# 686. Quimbaya
# 687. Quinchía
# 688. Quipile
# 689. Quípama
# 690. Ragonvalia
# 691. Ramiriquí
# 692. Recetor
# 693. Regidor
# 694. Remedios
# 695. Remolino
# 696. Repelón
# 697. Restrepo
# 698. Retiro
# 699. Ricaurte
# 700. Rioblanco
# 701. Riofrío
# 702. Riohacha (CT)
# 703. Rionegro
# 704. Riosucio
# 705. Risaralda
# 706. Rivera
# 707. Roberto Payán
# 708. Roldanillo
# 709. Roncesvalles
# 710. Rondón
# 711. Rosas
# 712. Rovira
# 713. Ráquira
# 714. Río Iro
# 715. Río Quito
# 716. Río Viejo
# 717. Río de Oro
# 718. Sabana de Torres
# 719. Sabanagrande
# 720. Sabanalarga
# 721. Sabanas de San Angel
# 722. Sabaneta
# 723. Saboyá
# 724. Sahagún
# 725. Saladoblanco
# 726. Salamina
# 727. Salazar
# 728. Saldaña
# 729. Salento
# 730. Salgar
# 731. Samacá
# 732. Samaniego
# 733. Samaná
# 734. Sampués
# 735. San Agustín
# 736. San Alberto
# 737. San Andres de Tumaco
# 738. San Andrés
# 739. San Andrés (CT)
# 740. San Andrés Sotavento
# 741. San Andrés de Cuerquía
# 742. San Antero
# 743. San Antonio
# 744. San Antonio del Tequendama
# 745. San Benito
# 746. San Benito Abad
# 747. San Bernardo
# 748. San Bernardo del Viento
# 749. San Calixto
# 750. San Carlos
# 751. San Carlos de Guaroa
# 752. San Cayetano
# 753. San Cristóbal
# 754. San Diego
# 755. San Eduardo
# 756. San Estanislao
# 757. San Fernando
# 758. San Francisco
# 759. San Gil
# 760. San Jacinto
# 761. San Jacinto del Cauca
# 762. San Jerónimo
# 763. San Joaquín
# 764. San José
# 765. San José de La Montaña
# 766. San José de Miranda
# 767. San José de Pare
# 768. San José de Uré
# 769. San José del Fragua
# 770. San José del Guaviare (CT)
# 771. San José del Palmar
# 772. San Juan Nepomuceno
# 773. San Juan de Arama
# 774. San Juan de Betulia
# 775. San Juan de Río Seco
# 776. San Juan de Urabá
# 777. San Juan del Cesar
# 778. San Juanito
# 779. San Lorenzo
# 780. San Luis
# 781. San Luis de Gaceno
# 782. San Luis de Palenque
# 783. San Luis de Sincé
# 784. San Marcos
# 785. San Martín
# 786. San Martín de Loba
# 787. San Mateo
# 788. San Miguel
# 789. San Miguel de Sema
# 790. San Onofre
# 791. San Pablo
# 792. San Pablo de Borbur
# 793. San Pedro
# 794. San Pedro de Cartago
# 795. San Pedro de Urabá
# 796. San Pelayo
# 797. San Rafael
# 798. San Roque
# 799. San Sebastián
# 800. San Sebastián de Buenavista
# 801. San Vicente
# 802. San Vicente de Chucurí
# 803. San Vicente del Caguán
# 804. San Zenón
# 805. Sandoná
# 806. Santa Ana
# 807. Santa Bárbara
# 808. Santa Bárbara de Pinto
# 809. Santa Catalina
# 810. Santa Helena del Opón
# 811. Santa Isabel
# 812. Santa Lucía
# 813. Santa Marta (CT)
# 814. Santa María
# 815. Santa Rosa
# 816. Santa Rosa de Cabal
# 817. Santa Rosa de Osos
# 818. Santa Rosa de Viterbo
# 819. Santa Rosa del Sur
# 820. Santa Rosalía
# 821. Santa Sofía
# 822. Santacruz
# 823. Santafé de Antioquia
# 824. Santana
# 825. Santander de Quilichao
# 826. Santiago
# 827. Santiago de Tolú
# 828. Santo Domingo
# 829. Santo Tomás
# 830. Santuario
# 831. Sapuyes
# 832. Saravena
# 833. Sardinata
# 834. Sasaima
# 835. Sativanorte
# 836. Sativasur
# 837. Segovia
# 838. Sesquilé
# 839. Sevilla
# 840. Siachoque
# 841. Sibaté
# 842. Sibundoy
# 843. Silos
# 844. Silvania
# 845. Silvia
# 846. Simacota
# 847. Simijaca
# 848. Simití
# 849. Sincelejo (CT)
# 850. Sipí
# 851. Sitionuevo
# 852. Soacha
# 853. Soatá
# 854. Socha
# 855. Socorro
# 856. Socotá
# 857. Sogamoso
# 858. Solano
# 859. Soledad
# 860. Solita
# 861. Somondoco
# 862. Sonson
# 863. Sopetrán
# 864. Soplaviento
# 865. Sopó
# 866. Sora
# 867. Soracá
# 868. Sotaquirá
# 869. Sotara
# 870. Suaita
# 871. Suan
# 872. Suaza
# 873. Subachoque
# 874. Sucre
# 875. Suesca
# 876. Supatá
# 877. Supía
# 878. Suratá
# 879. Susa
# 880. Susacón
# 881. Sutamarchán
# 882. Sutatausa
# 883. Sutatenza
# 884. Suárez
# 885. Sácama
# 886. Sáchica
# 887. Tabio
# 888. Tadó
# 889. Talaigua Nuevo
# 890. Tamalameque
# 891. Tame
# 892. Taminango
# 893. Tangua
# 894. Taraira
# 895. Tarazá
# 896. Tarqui
# 897. Tarso
# 898. Tasco
# 899. Tauramena
# 900. Tausa
# 901. Tello
# 902. Tena
# 903. Tenerife
# 904. Tenjo
# 905. Tenza
# 906. Teorama
# 907. Teruel
# 908. Tesalia
# 909. Tibacuy
# 910. Tibaná
# 911. Tibasosa
# 912. Tibirita
# 913. Tibú
# 914. Tierralta
# 915. Timaná
# 916. Timbiquí
# 917. Timbío
# 918. Tinjacá
# 919. Tipacoque
# 920. Tiquisio
# 921. Titiribí
# 922. Toca
# 923. Tocaima
# 924. Tocancipá
# 925. Togüí
# 926. Toledo
# 927. Tolú Viejo
# 928. Tona
# 929. Topaipí
# 930. Toribio
# 931. Toro
# 932. Tota
# 933. Totoró
# 934. Trinidad
# 935. Trujillo
# 936. Tubará
# 937. Tuchín
# 938. Tuluá
# 939. Tunja (CT)
# 940. Tununguá
# 941. Turbaco
# 942. Turbaná
# 943. Turbo
# 944. Turmequé
# 945. Tuta
# 946. Tutazá
# 947. Támara
# 948. Támesis
# 949. Tópaga
# 950. Túquerres
# 951. Ubalá
# 952. Ubaque
# 953. Ulloa
# 954. Umbita
# 955. Une
# 956. Unguía
# 957. Unión Panamericana
# 958. Uramita
# 959. Uribe
# 960. Uribia
# 961. Urrao
# 962. Urumita
# 963. Usiacurí
# 964. Valdivia
# 965. Valencia
# 966. Valle de San José
# 967. Valle de San Juan
# 968. Valle del Guamuez
# 969. Valledupar (CT)
# 970. Valparaíso
# 971. Vegachí
# 972. Venadillo
# 973. Venecia
# 974. Ventaquemada
# 975. Vergara
# 976. Versalles
# 977. Vetas
# 978. Vianí
# 979. Victoria
# 980. Vigía del Fuerte
# 981. Vijes
# 982. Villa Caro
# 983. Villa Rica
# 984. Villa de Leyva
# 985. Villa de San Diego de Ubate
# 986. Villa del Rosario
# 987. Villagarzón
# 988. Villagómez
# 989. Villahermosa
# 990. Villamaría
# 991. Villanueva
# 992. Villapinzón
# 993. Villarrica
# 994. Villavicencio (CT)
# 995. Villavieja
# 996. Villeta
# 997. Viotá
# 998. Viracachá
# 999. Vistahermosa
# 1000. Viterbo
# 1001. Vélez
# 1002. Yacopí
# 1003. Yacuanquer
# 1004. Yaguará
# 1005. Yalí
# 1006. Yarumal
# 1007. Yolombó
# 1008. Yondó
# 1009. Yopal (CT)
# 1010. Yotoco
# 1011. Yumbo
# 1012. Zambrano
# 1013. Zapatoca
# 1014. Zapayán
# 1015. Zaragoza
# 1016. Zarzal
# 1017. Zetaquira
# 1018. Zipacón
# 1019. Zipaquirá
# 1020. Zona Bananera
# 1021. Útica

# %% [markdown]
# ###  5.2.Obtener municipios comunes

# %% [markdown]
# ### 5.5.Verificar que ambas tienen los mismos municipios

# %%
df_suicidios_2024['Municipio del hecho DANE'] = (
    df_suicidios_2024['Municipio del hecho DANE']
    .str.upper()
    .str.strip()
)

df_delitos['MUNICIPIO'] = (
    df_delitos['MUNICIPIO']
    .str.upper()
    .str.strip()
)
# Out:
# /tmp/ipykernel_12918/3131937562.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_suicidios_2024['Municipio del hecho DANE'] = (

# %% [markdown]
# ### 5.6.Agrupar delitos filtrados por municipio y categoría

# %%
print("=== COLUMNAS AHORA ===")
print(df_delitos.columns.tolist())

print("\n=== PRIMERAS FILAS ===")
print(df_delitos[['DELITOS', 'CATEGORIA']].head(10))
# Out:
# === COLUMNAS AHORA ===
# ['ARMAS MEDIOS', 'DEPARTAMENTO', 'MUNICIPIO', 'FECHA HECHO', 'GENERO', '*AGRUPA EDAD PERSONA*', 'CODIGO DANE', 'DELITOS', 'MES', 'CANTIDAD', 'CATEGORIA']
#
# === PRIMERAS FILAS ===
#                                              DELITOS   CATEGORIA
# 0  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 1  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 2  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 3  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 4  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 5  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 6  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 7  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 8  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios
# 9  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...  Homicidios

# %% [markdown]
# ###  5.7.Top 20 municipios con mas delitos en Colombia

# %%
print(df_delitos[['MUNICIPIO', 'DELITOS', 'CANTIDAD']].head(20))
# Out:
#            MUNICIPIO                                            DELITOS  \
# 0      MEDELLÍN (CT)  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 1      MEDELLÍN (CT)  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 2           VALDIVIA  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 3      ZONA BANANERA  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 4             AMALFI  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 5             ZARZAL  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 6           CAUCASIA  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 7           RIOSUCIO  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 8             ITAGUI  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 9      MEDELLÍN (CT)  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 10           QUETAME  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 11       IBAGUÉ (CT)  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 12       PUERTO ASÍS  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 13       SAN JACINTO  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 14          PAILITAS  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 15        YOPAL (CT)  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 16        SANTA ROSA  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 17             HONDA  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 18  BOGOTÁ D.C. (CT)  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
# 19  BOGOTÁ D.C. (CT)  ARTÍCULO 109. HOMICIDIO CULPOSO ( EN ACCIDENTE...
#
#     CANTIDAD
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# 5        1.0
# 6        1.0
# 7        1.0
# 8        1.0
# 9        1.0
# 10       1.0
# 11       1.0
# 12       1.0
# 13       1.0
# 14       1.0
# 15       1.0
# 16       1.0
# 17       1.0
# 18       1.0
# 19       1.0

# %%
top20_general = (  df_delitos.groupby('MUNICIPIO')['CANTIDAD']  .sum()  .sort_values(ascending=False)  .head(20))

print(top20_general)
# Out:
# MUNICIPIO
# BOGOTÁ D.C. (CT)      248535.0
# MEDELLÍN (CT)          60706.0
# CALI (CT)              48905.0
# BARRANQUILLA (CT)      19386.0
# CARTAGENA (CT)         18627.0
# VILLAVICENCIO (CT)     14236.0
# IBAGUÉ (CT)            14110.0
# BUCARAMANGA (CT)       13988.0
# PASTO (CT)             13744.0
# SOACHA                 13597.0
# NEIVA (CT)             11429.0
# POPAYÁN (CT)            9639.0
# SANTA MARTA (CT)        9535.0
# CÚCUTA (CT)             9087.0
# VALLEDUPAR (CT)         8584.0
# PEREIRA (CT)            7816.0
# BELLO                   7662.0
# PALMIRA                 6902.0
# SOLEDAD                 5685.0
# BARRANCABERMEJA         5550.0
# Name: CANTIDAD, dtype: float64

# %%
import matplotlib.pyplot as plt

# Top 20 municipios con más delitos
top20_general = (df_delitos.groupby('MUNICIPIO')['CANTIDAD'].sum().sort_values(ascending=False).head(20))

plt.figure(figsize=(12, 8))

bars = plt.barh(
    range(len(top20_general)),
    top20_general.values,
    color='steelblue',
    edgecolor='black'
)

plt.yticks(range(len(top20_general)), top20_general.index)

plt.xlabel('Cantidad de Delitos', fontsize=12)

plt.title(
    'TOP 20 MUNICIPIOS CON MÁS DELITOS EN COLOMBIA',
    fontsize=14,
    fontweight='bold'
)

plt.gca().invert_yaxis()

# Agregar valores
for bar, val in zip(bars, top20_general.values):

    plt.text(
        val + 500,
        bar.get_y() + bar.get_height()/2,
        f'{int(val):,}',
        va='center',
        fontsize=9
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# ###  5.8.Top 15 municipios-porcentaje total de delitos en Colombia

# %%
# Calcular porcentaje de cada municipio sobre el total nacional
total_nacional = df_delitos['CANTIDAD'].sum()
top15 = df_delitos.groupby('MUNICIPIO')['CANTIDAD'].sum().sort_values(ascending=False).head(15)
top15_porcentaje = (top15 / total_nacional) * 100

plt.figure(figsize=(12, 8))
bars = plt.barh(range(len(top15_porcentaje)), top15_porcentaje.values, color='teal', edgecolor='black')
plt.yticks(range(len(top15_porcentaje)), top15_porcentaje.index)
plt.xlabel('Porcentaje del Total Nacional de Delitos (%)', fontsize=12)
plt.title('TOP 15 MUNICIPIOS - PORCENTAJE DEL TOTAL DE DELITOS EN COLOMBIA', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()

# Agregar valores
for i, (bar, val) in enumerate(zip(bars, top15_porcentaje.values)):
    plt.text(val + 0.5, bar.get_y() + bar.get_height()/2, f'{val:.2f}%',
             va='center', fontsize=9)

plt.tight_layout()
plt.show()

print(f"\n Los 5 municipios con mayor porcentaje concentran: {top15_porcentaje.head(5).sum():.2f}% de todos los delitos")
# Out:
#  Los 5 municipios con mayor porcentaje concentran: 47.49% de todos los delitos

# %% [markdown]
# ### 5.9.Delitos por categoria

# %%
import matplotlib.pyplot as plt

# Calcular porcentajes
total_nacional = df_delitos['CANTIDAD'].sum()
porcentaje_categoria = df_delitos.groupby('CATEGORIA')['CANTIDAD'].sum().sort_values(ascending=False)
porcentaje_categoria = (porcentaje_categoria / total_nacional) * 100

# Gráfico de barras
plt.figure(figsize=(12, 7))
bars = plt.bar(porcentaje_categoria.index, porcentaje_categoria.values,
               color='steelblue', edgecolor='black')

plt.title('Distribución de Delitos por Categoría en Colombia', fontsize=14, fontweight='bold')
plt.xlabel('Categoría', fontsize=12)
plt.ylabel('Porcentaje del Total Nacional (%)', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=11)

# Agregar valores en las barras
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
             f'{height:.1f}%', ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###  5.10.Top 5 municipios por categoria

# %%
# Top 5 por categoría (con los datos filtrados)
for categoria in df_delitos['CATEGORIA'].unique():
    top = df_delitos[df_delitos['CATEGORIA'] == categoria]
    top = top.sort_values('CANTIDAD', ascending=False).head(5)
    print(f"\n{'='*50}")
    print(f"TOP 5 MUNICIPIOS - {categoria}")
    print('='*50)
    for i, row in top.iterrows():
        print(f"{row['MUNICIPIO']}: {int(row['CANTIDAD']):,} delitos")
# Out:
# ==================================================
# TOP 5 MUNICIPIOS - Homicidios
# ==================================================
# MEDELLÍN (CT): 1 delitos
# MEDELLÍN (CT): 1 delitos
# MEDELLÍN (CT): 1 delitos
# VALDIVIA: 1 delitos
# ZONA BANANERA: 1 delitos
#
# ==================================================
# TOP 5 MUNICIPIOS - Lesiones Personales
# ==================================================
# SOGAMOSO: 1 delitos
# BOGOTÁ D.C. (CT): 1 delitos
# BOGOTÁ D.C. (CT): 1 delitos
# BOGOTÁ D.C. (CT): 1 delitos
# BOGOTÁ D.C. (CT): 1 delitos
#
# ==================================================
# TOP 5 MUNICIPIOS - Delitos Sexuales
# ==================================================
# BOGOTÁ D.C. (CT): 1 delitos
# SAN ANDRES DE TUMACO: 1 delitos
# SAN ANDRES DE TUMACO: 1 delitos
# SAMANIEGO: 1 delitos
# BOGOTÁ D.C. (CT): 1 delitos
#
# ==================================================
# TOP 5 MUNICIPIOS - Otros Delitos
# ==================================================
# BAGADÓ: 1 delitos
# BOGOTÁ D.C. (CT): 1 delitos
# BARRANCABERMEJA: 1 delitos
# TABIO: 1 delitos
# TABIO: 1 delitos
#
# ==================================================
# TOP 5 MUNICIPIOS - Hurto
# ==================================================
# PUERTO COLOMBIA: 1 delitos
# MAGANGUÉ: 1 delitos
# TUNJA (CT): 1 delitos
# BUCARAMANGA (CT): 1 delitos
# MAGANGUÉ: 1 delitos
#
# ==================================================
# TOP 5 MUNICIPIOS - Secuestro
# ==================================================
# SAN ANDRES DE TUMACO: 1 delitos
# SARAVENA: 1 delitos
# BUCARAMANGA (CT): 1 delitos
# OCAÑA: 1 delitos
# PURACÉ: 1 delitos

# %%
import matplotlib.pyplot as plt

# Lista de categorías
categorias = df_delitos['CATEGORIA'].unique()

# Guardar datos
datos = {}

# Crear top 5 por categoría
for cat in categorias:

    top = (
        df_delitos[
            df_delitos['CATEGORIA'] == cat
        ]
        .groupby('MUNICIPIO')['CANTIDAD']
        .sum()
        .sort_values(ascending=False)
        .head(5)
        .reset_index()
    )

    datos[cat] = {
        row['MUNICIPIO']: row['CANTIDAD']
        for _, row in top.iterrows()
    }

# Configurar gráficos
fig, axes = plt.subplots(2, 3, figsize=(16,10))

axes = axes.flatten()

# Crear cada gráfico
for i, cat in enumerate(categorias):

    municipios = list(datos[cat].keys())
    valores = list(datos[cat].values())

    bars = axes[i].barh(
        municipios,
        valores,
        color='coral',
        edgecolor='black'
    )

    axes[i].set_title(
        cat,
        fontsize=12,
        fontweight='bold'
    )

    axes[i].set_xlabel('Cantidad de Delitos')

    axes[i].invert_yaxis()

    # Agregar números
    for bar, val in zip(bars, valores):

        axes[i].text(
            val + 5,
            bar.get_y() + bar.get_height()/2,
            f'{int(val):,}',
            va='center',
            fontsize=9
        )

# Ocultar gráfico sobrante
if len(categorias) < 6:
    axes[-1].set_visible(False)

# Título general
plt.suptitle(
    'TOP 5 MUNICIPIOS POR CATEGORÍA DE DELITO',
    fontsize=16,
    fontweight='bold'
)

plt.tight_layout()

plt.show()

# %% [markdown]
# ###  5.11.Top 10 municipios con mas delitos mapa de calor

# %%
# Top 10 municipios con más delitos totales
top10_municipios = (df_delitos.groupby('MUNICIPIO')['CANTIDAD']
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .index
)

# Filtrar datos
top10_datos = df_delitos[df_delitos['MUNICIPIO'].isin(top10_municipios)]

# Pivotar correctamente
pivot_top10 = top10_datos.pivot_table(
    index='MUNICIPIO',
    columns='CATEGORIA',
    values='CANTIDAD',
    aggfunc='sum',
    fill_value=0
)

# Reordenar columnas
orden_cats = [
    'Hurto',
    'Otros Delitos',
    'Lesiones Personales',
    'Delitos Sexuales',
    'Homicidios',
    'Secuestro'
]

pivot_top10 = pivot_top10[orden_cats]

# Mapa de calor
fig, ax = plt.subplots(figsize=(12,8))

im = ax.imshow(
    pivot_top10.values,
    cmap='YlOrRd',
    aspect='auto'
)

# Configurar ejes
ax.set_xticks(range(len(pivot_top10.columns)))
ax.set_xticklabels(
    pivot_top10.columns,
    rotation=45,
    ha='right'
)

ax.set_yticks(range(len(pivot_top10.index)))
ax.set_yticklabels(pivot_top10.index)

ax.set_title(
    'Distribución de Delitos - Top 10 Municipios',
    fontsize=14,
    fontweight='bold'
)

# Valores dentro de celdas
for i in range(len(pivot_top10.index)):

    for j in range(len(pivot_top10.columns)):

        val = pivot_top10.values[i, j]

        if val > 0:

            text_color = (
                'white'
                if val > pivot_top10.values.max()/2
                else 'black'
            )

            ax.text(
                j,
                i,
                f'{int(val):,}',
                ha='center',
                va='center',
                color=text_color,
                fontsize=8
            )

plt.colorbar(im, ax=ax, label='Cantidad de Delitos')

plt.tight_layout()

plt.show()

# %% [markdown]
# ##  6.Estadisticas de numero de suicidios por municipios

# %%
# Suicidios por municipio (todos)
suicidios_por_municipio = df_suicidios_2024.groupby('Municipio del hecho DANE').size().reset_index(name='SUICIDIOS')
suicidios_por_municipio = suicidios_por_municipio.sort_values('SUICIDIOS', ascending=False)

print("="*60)
print("SUICIDIOS POR MUNICIPIO")
print("="*60)
print(f"Total de municipios: {len(suicidios_por_municipio)}")
print(f"Total de suicidios: {suicidios_por_municipio['SUICIDIOS'].sum()}")
print("\nLista completa:")
print(suicidios_por_municipio.to_string(index=False))
# Out:
# ============================================================
# SUICIDIOS POR MUNICIPIO
# ============================================================
# Total de municipios: 611
# Total de suicidios: 3014
#
# Lista completa:
#    Municipio del hecho DANE  SUICIDIOS
#                BOGOTÁ, D.C.        363
#                    MEDELLÍN        194
#                        CALI        131
#                       PASTO         51
#                      CÚCUTA         50
#                     PEREIRA         47
#                       BELLO         45
#               VILLAVICENCIO         43
#                      IBAGUÉ         37
#                BARRANQUILLA         36
#                     POPAYÁN         35
#                 SANTA MARTA         34
#                 BUCARAMANGA         33
#         CARTAGENA DE INDIAS         33
#                      SOACHA         32
#                   MANIZALES         28
#                  VALLEDUPAR         27
#                       NEIVA         23
#                   FLORENCIA         23
#                     ARMENIA         22
#                    MONTERÍA         22
#                   SINCELEJO         21
#                     PALMIRA         21
#                  FACATATIVÁ         19
#        SAN ANDRÉS DE TUMACO         18
#                      ITAGÜÍ         17
#                    RIONEGRO         16
#                     IPIALES         15
#                        CHÍA         15
#                   ZIPAQUIRÁ         14
#                  FUSAGASUGÁ         14
#                       TULUÁ         13
#                       OCAÑA         13
#                       TURBO         12
#                    SOGAMOSO         12
#                       TUNJA         12
#                     SOLEDAD         12
#                  CANDELARIA         11
#                BUENAVENTURA         11
#                     CARTAGO         11
#                     CALARCÁ         10
#                 PIEDECUESTA         10
#         SANTA ROSA DE CABAL         10
#                  COPACABANA         10
#               FLORIDABLANCA         10
#                     ESPINAL         10
#                DOSQUEBRADAS         10
#         GUADALAJARA DE BUGA         10
#                     YARUMAL         10
#                        MITÚ          9
#                      CALDAS          9
#                    GIRARDOT          9
#                       YOPAL          9
#             BARRANCABERMEJA          9
#                      GUARNE          9
#                      GARZÓN          9
#                        TAME          9
#                    RIOHACHA          8
#                      QUIBDÓ          8
#                     LA CEJA          8
#                    ENVIGADO          8
#                      MADRID          8
#                     SAHAGÚN          8
#                    SABANETA          8
#                    LA UNIÓN          8
#                     BOLÍVAR          7
#                    PITALITO          7
#                     LETICIA          7
#                   LA DORADA          7
#                     GRANADA          7
#                       YUMBO          7
#                     AGUADAS          7
#        EL CARMEN DE VIBORAL          7
#                     SAN GIL          7
#                  LOS PATIOS          7
#                   TIERRALTA          6
#        EL CARMEN DE BOLÍVAR          6
#                    EL BAGRE          6
#       SAN JOSÉ DEL GUAVIARE          6
#               PUERTO BOYACÁ          6
#                     INÍRIDA          6
#                    APARTADÓ          6
#                   AGUACHICA          6
#                       PEÑOL          6
#                     MALAMBO          6
#                      MAICAO          6
# VILLA DE SAN DIEGO DE UBATÉ          6
#                    MAGANGUÉ          6
#         LA JAGUA DE IBIRICO          6
#                      LORICA          6
#               PUERTO GAITÁN          6
#                    LA PLATA          6
#                      CAJICÁ          6
#                      CAREPA          6
#                      MOMPÓS          6
#                    PAMPLONA          6
#                       PIJAO          5
#                   ARAUQUITA          5
#                    SARAVENA          5
#                       ORITO          5
#                       URRAO          5
#                     CAJIBÍO          5
#      SANTANDER DE QUILICHAO          5
#                   CHAPARRAL          5
#                      MUTATÁ          5
#                       NEIRA          5
#                     TURBACO          5
#                      PÁCORA          5
#                       FUNZA          5
#                    EL TAMBO          5
#                 MONTELÍBANO          5
#                     ANSERMA          5
#                    RIOSUCIO          5
#                        AIPE          5
#                 PUERTO ASÍS          5
#                CHIQUINQUIRÁ          5
#                  SAN ANDRÉS          5
#   SAN PEDRO DE LOS MILAGROS          5
#                     DUITAMA          5
#      SAN VICENTE DEL CAGUÁN          5
#       SANTA FÉ DE ANTIOQUIA          5
#                      LÍBANO          5
#                   ALGECIRAS          4
#                    EL TARRA          4
#                    EL ROSAL          4
#                      LÉRIDA          4
#                     ISTMINA          4
#                      ARAUCA          4
#                       ANDES          4
#                   LA CALERA          4
#             AGUSTÍN CODAZZI          4
#                      AMALFI          4
#                     JAMUNDÍ          4
#                  ROLDANILLO          4
#                     ITUANGO          4
#                 LA ESTRELLA          4
#                   LA GLORIA          4
#                SABANAGRANDE          4
#                       GIRÓN          4
#                   VENADILLO          4
#                    MOSQUERA          4
#                    ARIGUANÍ          4
#                       TABIO          4
#                   TAMINANGO          4
#                     TEORAMA          4
#                   CHIGORODÓ          4
#                        TIBÚ          4
#                   CHINCHINÁ          4
#                      SIBATÉ          4
#                     SEVILLA          4
#                 PALOCABILDO          4
#           VILLA DEL ROSARIO          4
#                  VILLAMARÍA          4
#                     ACACÍAS          4
#                   ABEJORRAL          4
#                   SANTUARIO          4
#                   SARDINATA          4
#                 CAÑASGORDAS          4
#                     EL PASO          4
#                   CUMBITARA          4
#  SAN SEBASTIÁN DE MARIQUITA          4
#                  SAN PELAYO          4
#                 PUEBLO RICO          4
#                   GIRARDOTA          4
#            SABANA DE TORRES          4
#                    GUATEQUE          4
#                  SAN MARCOS          4
#                LA PRIMAVERA          4
#              CIUDAD BOLÍVAR          4
#          SANTA ROSA DE OSOS          4
#                  CAMPAMENTO          4
#                  SITIONUEVO          3
#                  MANZANARES          3
#                   MARINILLA          3
#                        MANÍ          3
#                    CAUCASIA          3
#                      CERETÉ          3
#                    PIENDAMÓ          3
#                    PLANADAS          3
#                      SONSÓN          3
#                      SORACÁ          3
#                    TIBASOSA          3
#                   CAJAMARCA          3
#                      PELAYA          3
#                   MONIQUIRÁ          3
#                 CAMPOALEGRE          3
#                       CHINÚ          3
#                      MELGAR          3
#                    BOSCONIA          3
#           VALLE DEL GUAMUEZ          3
#                     PALERMO          3
#                    PAILITAS          3
#                 VILLAGARZÓN          3
#                  VILLANUEVA          3
#                       PAIPA          3
#                   TÚQUERRES          3
#                      TOTORÓ          3
#                      ARJONA          3
#                        TADÓ          3
#                      TIMBÍO          3
#                PLANETA RICA          3
#                        COTA          3
#               MARÍA LA BAJA          3
#                    LA PALMA          3
#                    PUPIALES          3
#                 PUERTO RICO          3
#                      SAMANÁ          3
#                     FONSECA          3
#           SAN LUIS DE SINCÉ          3
#        EL CARMEN DE CHUCURÍ          3
#             PUERTO COLOMBIA          3
#                    SAN LUIS          3
#                  SAN MIGUEL          3
#                      FRESNO          3
#                     LEBRIJA          3
#             PUENTE NACIONAL          3
#                   EL CHARCO          3
#                   DONMATÍAS          3
#                       DAGUA          3
#                     GUACARÍ          3
#                    SALAMINA          3
#                SALADOBLANCO          3
#                 SABANALARGA          3
#                     GINEBRA          3
#                     GARAGOA          3
#                    QUINCHÍA          3
#                    RESTREPO          3
#                   FUNDACIÓN          3
#                      RIVERA          3
#                      HERVEO          3
#                        INZÁ          3
#                       YONDÓ          3
#                       VÉLEZ          3
#                    ANOLAIMA          3
#                        APÍA          3
#                     ARATOCA          2
#                    ARANZAZU          2
#                  ANZOÁTEGUI          2
#                 ANGELÓPOLIS          2
#                     BARBOSA          2
#                   BARBACOAS          2
#                      BALBOA          2
#                      AYAPEL          2
#             ARMERO GUAYABAL          2
#                     ZIPACÓN          2
#                   ZETAQUIRA          2
#                     VITERBO          2
#                      ALCALÁ          2
#                AGUA DE DIOS          2
#                       ISNOS          2
#                      JARDÍN          2
#                    GUACHENÉ          2
#                   SAMANIEGO          2
#                  RÍO DE ORO          2
#                      ROVIRA          2
#                      RETIRO          2
#                   RAMIRIQUÍ          2
#                    QUIMBAYA          2
#                     LA VEGA          2
#                   LA SIERRA          2
#                     GALERAS          2
#                  GACHANCIPÁ          2
#               FUENTE DE ORO          2
#                       GUAMO          2
#                     GUADUAS          2
#                   GUACHUCAL          2
#                     FLANDES          2
#                    EL ZULIA          2
#               SAN FRANCISCO          2
#                SAN CAYETANO          2
#        SAN CARLOS DE GUAROA          2
#                     LA MESA          2
#              PUERTO WILCHES          2
#               PUERTO TEJADA          2
#                PUERTO LÓPEZ          2
#           PUERTO LIBERTADOR          2
#            PUERTO LEGUÍZAMO          2
#              PUERTO CAICEDO          2
#                  EL CERRITO          2
#                   EL CARMEN          2
#                  SAN ONOFRE          2
#         SAN JUAN DE RIOSECO          2
#                    FRONTINO          2
#                      FORTUL          2
#                   SAN PEDRO          2
#                     DIBULLA          2
#                     DABEIBA          2
#                     CÓRDOBA          2
#                     CÓMBITA          2
#                      CURITÍ          2
#                    EL DOVIO          2
#                   LANDÁZURI          2
#                     PUERRES          2
#                     PRADERA          2
#                      CUMBAL          2
#                   CUCUTILLA          2
#                     COROZAL          2
#                   CONCORDIA          2
#                  CONCEPCIÓN          2
#                SANTA ISABEL          2
#                   SAN ROQUE          2
#                     SOCORRO          2
#                    SIBUNDOY          2
#                 SANTO TOMÁS          2
#                    SANTIAGO          2
#                    MARSELLA          2
#                      MANATÍ          2
#                     MALLAMA          2
#                       SUAZA          2
#                      SOLANO          2
#                       COLÓN          2
#                     COCORNÁ          2
#                     CIÉNAGA          2
#                   CIMITARRA          2
#                      SUÁREZ          2
#        CARTAGENA DEL CHAIRÁ          2
#           CARMEN DE APICALÁ          2
#                    CANALETE          2
#                      CALIMA          2
#                   CHINÁCOTA          2
#                 PENSILVANIA          2
#              PAZ DE ARIPORO          2
#                       PATÍA          2
#                  MONTENEGRO          2
#                       MOMIL          2
#                     MESETAS          2
#                     CALAMAR          2
#                  BUENAVISTA          2
#                      TIMANÁ          2
#                      BOJACÁ          2
#             BELÉN DE UMBRÍA          2
#                  BELALCÁZAR          2
#                   TOCANCIPÁ          2
#                     ARGELIA          2
#                    VALDIVIA          2
#                    USIACURÍ          2
#                     URUMITA          2
#                       URIBE          2
#                      BOYACÁ          2
#                     MOÑITOS          2
#                     MORALES          2
#                     PALMITO          2
#                   PALESTINA          2
#                      OVEJAS          2
#                     ACEVEDO          2
#                      ACANDÍ          2
#              VILLA DE LEYVA          2
#                      ÁBREGO          1
#                      AGRADO          1
#                     ALBANIA          1
#                       ALBÁN          1
#                    ALMAGUER          1
#                    ALVARADO          1
#                      YACOPÍ          1
#                     YAGUARÁ          1
#                    AMBALEMA          1
#                      ATRATO          1
#                       ATACO          1
#                      ASTREA          1
#                    ARCABUCO          1
#                    ARBOLEDA          1
#                       VIANÍ          1
#                     VERGARA          1
#                     VEGACHÍ          1
#                    VALENCIA          1
#          UNIÓN PANAMERICANA          1
#                       UBALÁ          1
#                      TÓPAGA          1
#                      BOJAYÁ          1
#                   BOCHALEMA          1
#                     BETANIA          1
#                    MAJAGUAL          1
#                     MAHATES          1
#                     PIVIJAY          1
#                       PITAL          1
#           PIJIÑO DEL CARMEN          1
#                     PIEDRAS          1
#                   MONTERREY          1
#                  MONTEBELLO          1
#                     MOGOTES          1
#                       MOCOA          1
#                    MISTRATÓ          1
#                     MIRANDA          1
#                 MEDIO BAUDÓ          1
#               OLAYA HERRERA          1
#                       OLAYA          1
#                     NUNCHÍA          1
#                LOS CÓRDOBAS          1
#                    LIBORINA          1
#                 LENGUAZAQUE          1
#                       LEIVA          1
#               PUERTO BERRÍO          1
#                 PUEBLOVIEJO          1
#                PUEBLO NUEVO          1
#                 PROVIDENCIA          1
#                       PRADO          1
#                        PORE          1
#                    PONEDERA          1
#                   POLONUEVO          1
#                   POLICARPA          1
#                     MATANZA          1
#                     MARMATO          1
#    MANAURE BALCÓN DEL CESAR          1
#                    LABATECA          1
#                 LA VICTORIA          1
#                  LA TEBAIDA          1
#                   LA SALINA          1
#                  LA PINTADA          1
#                   LA MERCED          1
#                  LA LLANADA          1
#          LA JAGUA DEL PILAR          1
#               PUERTO LLERAS          1
#               PUERTO GUZMÁN          1
#            PUERTO ESCONDIDO          1
#            PUERTO CONCORDIA          1
#              PUERTO CARREÑO          1
#                       MACEO          1
#                     LURUACO          1
#                     LOURDES          1
#                     GUÁTICA          1
#                  LA FLORIDA          1
#                LA ESPERANZA          1
#                   LA CUMBRE          1
#                     LA CRUZ          1
#                LA ARGENTINA          1
#                 LA APARTADA          1
#                 JESÚS MARÍA          1
#                      JERICÓ          1
#                   RIOBLANCO          1
#                    RICAURTE          1
#                     REPELÓN          1
#                    REMOLINO          1
#                    REMEDIOS          1
#                     QUIPILE          1
#                      PURACÉ          1
#                       FUNES          1
#                  GUAYABETAL          1
#                      GUASCA          1
#                     GUAPOTÁ          1
#                      GUAMAL          1
#                    GUACHETÁ          1
#                      SAMACÁ          1
#                      SABOYÁ          1
#               ROBERTO PAYÁN          1
#                    HISPANIA          1
#                   HATONUEVO          1
#                      HACARÍ          1
#                      GÜICÁN          1
#                 GÓMEZ PLATA          1
#                      GÉNOVA          1
#                     GÁMBITA          1
#                  FILADELFIA          1
#                EL SANTUARIO          1
#              SAN ESTANISLAO          1
#                  SAN CARLOS          1
#                 SAN CALIXTO          1
#     SAN BERNARDO DEL VIENTO          1
#             SAN BENITO ABAD          1
#                  SAN ANTERO          1
#     SAN ANDRÉS DE SOTAVENTO          1
#                 SAN AGUSTÍN          1
#                     SAMPUÉS          1
#                     GIGANTE          1
#                       GALÁN          1
#                      GALAPA          1
#                  GACHANTIVÁ          1
#                     FÓMEQUE          1
#                    EL RETÉN          1
#                   EL PLAYÓN          1
#                    EL PEÑÓN          1
#                   EL DORADO          1
#                 EL DONCELLO          1
#                  EL COLEGIO          1
#                  SAN MARTÍN          1
#          SAN LUIS DE GACENO          1
#        SAN LUIS DE CUBARRAL          1
#         SAN JUAN NEPOMUCENO          1
#          SAN JUAN DEL CESAR          1
#           SAN JUAN DE ARAMA          1
#         SAN JOSÉ DEL FRAGUA          1
#      SAN JOSÉ DE LA MONTAÑA          1
#                 SAN JACINTO          1
#                     FLORIDA          1
#                  CONVENCIÓN          1
#                   CONTADERO          1
#                     CONSACÁ          1
#                 SANTA MARÍA          1
#                     SANDONÁ          1
#          SAN VICENTE FERRER          1
#      SAN VICENTE DE CHUCURÍ          1
#          SAN PEDRO DE URABÁ          1
#        SAN PEDRO DE CARTAGO          1
#                   SAN PABLO          1
#                    EL CAIRO          1
#                 DISTRACCIÓN          1
#                     CÁQUEZA          1
#                     CÁCHIRA          1
#                     CUÍTIVA          1
#                    EL ROBLE          1
#                      SILVIA          1
#                    SILVANIA          1
#                   SIACHOQUE          1
#                     SEGOVIA          1
#                   SATIVASUR          1
#                     SASAIMA          1
#               SANTO DOMINGO          1
#            SANTIAGO DE TOLÚ          1
#          SANTA ROSA DEL SUR          1
#       SANTA ROSA DE VITERBO          1
#                  SANTA ROSA          1
#                     CURILLO          1
#                     CUMARAL          1
#                    CUCUNUBÁ          1
#                     COVEÑAS          1
#                     CORINTO          1
#                    SOPETRÁN          1
#                      COLOSO          1
#                    COLOMBIA          1
#                   CLEMENCIA          1
#                     CIÉNEGA          1
#              CIÉNAGA DE ORO          1
#                    CHOCONTÁ          1
#                     CHITAGÁ          1
#                     CHISCAS          1
#                  CHIRIGUANÁ          1
#                      SOCOTÁ          1
#                       SOCHA          1
#             SIN INFORMACIÓN          1
#                      SIMITÍ          1
#                    SIMIJACA          1
#                    SIMACOTA          1
#                 CHIMICHAGUA          1
#                       CHIMA          1
#                    CHAGUANÍ          1
#                   CHACHAGÜÍ          1
#                     CERINZA          1
#           CASTILLA LA NUEVA          1
#                  CASABIANCA          1
#                   SUTATAUSA          1
#                     SUSACÓN          1
#                        SUSA          1
#                       SUPÍA          1
#                      SUESCA          1
#                  SUBACHOQUE          1
#                      SUAITA          1
#                        SOPÓ          1
#                 SOPLAVIENTO          1
#                    BUSBANZÁ          1
#                BUGALAGRANDE          1
#                     BUESACO          1
#                  BUCARASICA          1
#                       TENZA          1
#                       TELLO          1
#                       TAUSA          1
#                   TAURAMENA          1
#                      TARQUI          1
#              TALAIGUA NUEVO          1
#                    CAROLINA          1
#           CARMEN DEL DARIÉN          1
#            CARMEN DE CARUPA          1
#                  CAPITANEJO          1
#                      CALOTO          1
#                     CALDONO          1
#             BELÉN DE BAJIRÁ          1
#                     BELMIRA          1
#                    BECERRIL          1
#                   BARRANCAS          1
#                      TÁMARA          1
#                        TUTA          1
#                    TRUJILLO          1
#                    TRINIDAD          1
#                     TORIBÍO          1
#                        TONA          1
#                  TOLÚ VIEJO          1
#                        TOCA          1
#                   TIPACOQUE          1
#                  CAICEDONIA          1
#                     CAICEDO          1
#                    CACHIPAY          1
#                     YOLOMBÓ          1
#               ZONA BANANERA          1
#                VISTAHERMOSA          1
#                       VIOTÁ          1
#                     VILLETA          1
#                  VILLAVIEJA          1
#                  VILLARRICA          1
#                VILLAHERMOSA          1
#                  VILLA RICA          1
#            VIGÍA DEL FUERTE          1
#                    VICTORIA          1
#                   AQUITANIA          1
#                        ANZÁ          1
#                       ANORÍ          1
#                   ANDALUCÍA          1
#                    ANAPOIMA          1
#                        NILO          1
#                     NEMOCÓN          1
#                     NECOCLÍ          1
#                      MÁLAGA          1
#                    MUTISCUA          1
#                      MORROA          1
#                       PASCA          1
#                 PARATEBUENO          1
#            PALMAR DE VARELA          1
#                       PAIME          1
#                      PAICOL          1
#                      OROCUÉ          1
#                      ZARZAL          1
#                    ZARAGOZA          1
#                    ZAPATOCA          1
#                      YOTOCO          1

# %%
import matplotlib.pyplot as plt

# Calcular suicidios por municipio
suicidios_por_municipio = df_suicidios_2024.groupby('Municipio del hecho DANE').size().reset_index(name='SUICIDIOS')
suicidios_por_municipio = suicidios_por_municipio.sort_values('SUICIDIOS', ascending=False)

# Top 15
top15 = suicidios_por_municipio.head(15)

# Gráfico de números
plt.figure(figsize=(12, 8))
bars = plt.barh(range(len(top15)), top15['SUICIDIOS'], color='steelblue', edgecolor='black')
plt.yticks(range(len(top15)), top15['Municipio del hecho DANE'])
plt.xlabel('Número de Suicidios', fontsize=12)
plt.title('TOP 15 MUNICIPIOS CON MÁS SUICIDIOS', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()

# Agregar valores en las barras
for i, (bar, val) in enumerate(zip(bars, top15['SUICIDIOS'])):
    plt.text(val + 0.5, bar.get_y() + bar.get_height()/2,
             f'{int(val)}', va='center', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
# Calcular porcentaje
total_suicidios = suicidios_por_municipio['SUICIDIOS'].sum()
suicidios_por_municipio['PORCENTAJE'] = (suicidios_por_municipio['SUICIDIOS'] / total_suicidios) * 100

# Top 15
top15 = suicidios_por_municipio.head(15)

# Gráfico de porcentajes
plt.figure(figsize=(12, 8))
bars = plt.barh(range(len(top15)), top15['PORCENTAJE'], color='coral', edgecolor='black')
plt.yticks(range(len(top15)), top15['Municipio del hecho DANE'])
plt.xlabel('Porcentaje del Total Nacional de Suicidios (%)', fontsize=12)
plt.title('TOP 15 MUNICIPIOS - PORCENTAJE DE SUICIDIOS', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()

# Agregar valores en las barras
for i, (bar, val) in enumerate(zip(bars, top15['PORCENTAJE'])):
    plt.text(val + 0.3, bar.get_y() + bar.get_height()/2,
             f'{val:.1f}%', va='center', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##  7.Estadisticas generales de variables de la base de suicidios

# %% [markdown]
# ###  7.1.edad

# %%
import matplotlib.pyplot as plt

print("="*60)
print("ESTADÍSTICAS - GRUPO DE EDAD QUINQUENAL")
print("="*60)

edad_stats = df_suicidios_2024['Grupo de Edad Quinquenal '].value_counts()
edad_pct = (edad_stats / len(df_suicidios_2024)) * 100

edad_df = pd.DataFrame({
    'Cantidad': edad_stats,
    'Porcentaje (%)': edad_pct.round(1)
})
print(edad_df)
# Out:
# ============================================================
# ESTADÍSTICAS - GRUPO DE EDAD QUINQUENAL
# ============================================================
#                            Cantidad  Porcentaje (%)
# Grupo de Edad Quinquenal
# (20 a 24)                       415            13.8
# (25 a 29)                       377            12.5
# (30 a 34)                       295             9.8
# (35 a 39)                       278             9.2
# (40 a 44)                       216             7.2
# (55 a 59)                       181             6.0
# (15 a 17)                       173             5.7
# (45 a 49)                       167             5.5
# (50 a 54)                       165             5.5
# (60 a 64)                       158             5.2
# (18 a 19)                       142             4.7
# (65 a 69)                       138             4.6
# (10 a 14)                       112             3.7
# (70 a 74)                        95             3.2
# (75 a 79)                        53             1.8
# (80 y más)                       47             1.6
# (05 a 09)                         2             0.1

# %%
# Gráfico
plt.figure(figsize=(14, 6))
edad_stats.plot(kind='bar', color='steelblue', edgecolor='black')
plt.title('Distribución de Suicidios por Grupo de Edad', fontsize=14, fontweight='bold')
plt.xlabel('Grupo de Edad', fontsize=12)
plt.ylabel('Cantidad de Suicidios', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.2.Grupo Mayor o Menor de Edad

# %%
print("="*60)
print("ESTADÍSTICAS - GRUPO MAYOR/MENOR DE EDAD")
print("="*60)

grupo_edad_stats = df_suicidios_2024['Grupo Mayor Menor de Edad'].value_counts()
grupo_edad_pct = (grupo_edad_stats / len(df_suicidios_2024)) * 100

grupo_df = pd.DataFrame({
    'Cantidad': grupo_edad_stats,
    'Porcentaje (%)': grupo_edad_pct.round(1)
})
print(grupo_df)
# Out:
# ============================================================
# ESTADÍSTICAS - GRUPO MAYOR/MENOR DE EDAD
# ============================================================
#                                Cantidad  Porcentaje (%)
# Grupo Mayor Menor de Edad
# b) Mayores de Edad (>18 años)      2727            90.5
# a) Menores de Edad (<18 años)       287             9.5

# %%
# Gráfico
plt.figure(figsize=(6, 5))
grupo_edad_stats.plot(kind='bar', color='coral', edgecolor='black')
plt.title('Suicidios - Mayor vs Menor de Edad', fontsize=14, fontweight='bold')
plt.xlabel('Grupo', fontsize=12)
plt.ylabel('Cantidad de Suicidios', fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.3.Sexo de la Víctima

# %%
print("="*60)
print(" ESTADÍSTICAS - SEXO DE LA VÍCTIMA")
print("="*60)

sexo_stats = df_suicidios_2024['Sexo de la victima'].value_counts()
sexo_pct = (sexo_stats / len(df_suicidios_2024)) * 100

sexo_df = pd.DataFrame({
    'Cantidad': sexo_stats,
    'Porcentaje (%)': sexo_pct.round(1)
})
print(sexo_df)
# Out:
# ============================================================
#  ESTADÍSTICAS - SEXO DE LA VÍCTIMA
# ============================================================
#                     Cantidad  Porcentaje (%)
# Sexo de la victima
# Hombre                  2421            80.3
# Mujer                    593            19.7

# %%
# Gráfico
plt.figure(figsize=(6, 6))
plt.pie(sexo_stats, labels=sexo_stats.index, autopct='%1.1f%%', startangle=90,
        colors=['lightcoral', 'lightblue'])
plt.title('Distribución de Suicidios por Sexo', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  7.4.Estado Civil

# %%
print("="*60)
print("ESTADÍSTICAS - ESTADO CIVIL")
print("="*60)

civil_stats = df_suicidios_2024['Estado Civil'].value_counts()
civil_pct = (civil_stats / len(df_suicidios_2024)) * 100

civil_df = pd.DataFrame({
    'Cantidad': civil_stats,
    'Porcentaje (%)': civil_pct.round(1)
})
print(civil_df)
# Out:
# ============================================================
# ESTADÍSTICAS - ESTADO CIVIL
# ============================================================
#                             Cantidad  Porcentaje (%)
# Estado Civil
# Soltero(a)                      1432            47.5
# Unión libre                      710            23.6
# Sin información                  389            12.9
# Casado(a)                        324            10.7
# Separado(a), divorciado(a)       107             3.6
# Viudo(a)                          50             1.7
# No aplica                          2             0.1

# %%
# Gráfico
plt.figure(figsize=(12, 6))
civil_stats.plot(kind='bar', color='teal', edgecolor='black')
plt.title('Distribución de Suicidios por Estado Civil', fontsize=14, fontweight='bold')
plt.xlabel('Estado Civil', fontsize=12)
plt.ylabel('Cantidad de Suicidios', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  7.5.País de Nacimiento

# %%
print("="*60)
print("ESTADÍSTICAS - PAÍS DE NACIMIENTO")
print("="*60)

pais_stats = df_suicidios_2024['País de Nacimiento'].value_counts()
pais_pct = (pais_stats / len(df_suicidios_2024)) * 100

pais_df = pd.DataFrame({
    'Cantidad': pais_stats,
    'Porcentaje (%)': pais_pct.round(1)
})
print(pais_df.head(10))
# Out:
# ============================================================
# ESTADÍSTICAS - PAÍS DE NACIMIENTO
# ============================================================
#                     Cantidad  Porcentaje (%)
# País de Nacimiento
# Colombia                2920            96.9
# Venezuela                 71             2.4
# Estados Unidos             3             0.1
# Sin información            3             0.1
# España                     2             0.1
# Alemania                   2             0.1
# Argentina                  2             0.1
# Ecuador                    2             0.1
# Filipinas                  1             0.0
# Lituania                   1             0.0

# %%
# Gráfico (top 5)
plt.figure(figsize=(10, 6))
pais_stats.head(5).plot(kind='bar', color='forestgreen', edgecolor='black')
plt.title('Top 5 Países de Nacimiento - Suicidios', fontsize=14, fontweight='bold')
plt.xlabel('País', fontsize=12)
plt.ylabel('Cantidad de Suicidios', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  7.6.Escenario del Hecho

# %%
print("="*60)
print("ESTADÍSTICAS - ESCENARIO DEL HECHO")
print("="*60)

escenario_stats = df_suicidios_2024['Escenario del Hecho'].value_counts()
escenario_pct = (escenario_stats / len(df_suicidios_2024)) * 100

escenario_df = pd.DataFrame({
    'Cantidad': escenario_stats,
    'Porcentaje (%)': escenario_pct.round(1)
})
print(escenario_df.head(10))
# Out:
# ============================================================
# ESTADÍSTICAS - ESCENARIO DEL HECHO
# ============================================================
#                                                     Cantidad  Porcentaje (%)
# Escenario del Hecho
# Vivienda                                                2203            73.1
# Vía pública                                              151             5.0
# Zonas de actividades agropecuarias                       141             4.7
# Espacios terrestres al aire libre (bosque, potr...       118             3.9
# Otros                                                     94             3.1
# Sin información                                           80             2.7
# Lugares de hospedaje (hoteles, campamentos y ot...        50             1.7
# Guarniciones militares y/o de policía                     23             0.8
# Centros de reclusión                                      20             0.7
# Espacios acuáticos al aire libre (mar, río, arr...        20             0.7

# %%
# Gráfico
plt.figure(figsize=(12, 6))
escenario_stats.head(8).plot(kind='bar', color='purple', edgecolor='black')
plt.title('Top 8 Escenarios de Suicidio', fontsize=14, fontweight='bold')
plt.xlabel('Escenario', fontsize=12)
plt.ylabel('Cantidad de Suicidios', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_12918/613273142.py:8: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### 7.7.Mecanismo Causal de la Lesión Fatal

# %%
print("="*60)
print(" ESTADÍSTICAS - MECANISMO CAUSAL")
print("="*60)

mecanismo_stats = df_suicidios_2024['Mecanismo Causal de la Lesión Fatal'].value_counts()
mecanismo_pct = (mecanismo_stats / len(df_suicidios_2024)) * 100

mecanismo_df = pd.DataFrame({
    'Cantidad': mecanismo_stats,
    'Porcentaje (%)': mecanismo_pct.round(1)
})
print(mecanismo_df)
# Out:
# ============================================================
#  ESTADÍSTICAS - MECANISMO CAUSAL
# ============================================================
#                                      Cantidad  Porcentaje (%)
# Mecanismo Causal de la Lesión Fatal
# Generadores de asfixia                   2128            70.6
# Tóxico                                    387            12.8
# Proyectil de arma de fuego                248             8.2
# Contundente                               190             6.3
# Cortopunzante                              30             1.0
# Cortante                                   17             0.6
# Térmico                                    13             0.4
# Cortocontundente                            1             0.0

# %%
# Gráfico
plt.figure(figsize=(10, 6))
mecanismo_stats.plot(kind='bar', color='darkorange', edgecolor='black')
plt.title('Mecanismo Causal de Lesión Fatal', fontsize=14, fontweight='bold')
plt.xlabel('Mecanismo', fontsize=12)
plt.ylabel('Cantidad de Suicidios', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##  8.Estadisticas generales de las variables en relacion con los municipio

# %% [markdown]
# ### 8.1.edad

# %%
# Edad por municipio - top 5 municipios con más suicidios
top_municipios = df_suicidios_2024['Municipio del hecho DANE'].value_counts().head(5).index

for municipio in top_municipios:
    print(f"\n{'='*60}")
    print(f" {municipio} - GRUPO DE EDAD")
    print('='*60)
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    edad_stats = datos_mun['Grupo de Edad Quinquenal '].value_counts()
    edad_pct = (edad_stats / len(datos_mun)) * 100
    edad_df = pd.DataFrame({'Cantidad': edad_stats, 'Porcentaje (%)': edad_pct.round(1)})
    print(edad_df)
# Out:
# ============================================================
#  BOGOTÁ, D.C. - GRUPO DE EDAD
# ============================================================
#                            Cantidad  Porcentaje (%)
# Grupo de Edad Quinquenal
# (25 a 29)                        55            15.2
# (20 a 24)                        54            14.9
# (30 a 34)                        46            12.7
# (40 a 44)                        36             9.9
# (35 a 39)                        29             8.0
# (15 a 17)                        21             5.8
# (50 a 54)                        19             5.2
# (18 a 19)                        18             5.0
# (45 a 49)                        17             4.7
# (55 a 59)                        17             4.7
# (65 a 69)                        13             3.6
# (60 a 64)                        11             3.0
# (10 a 14)                        10             2.8
# (70 a 74)                         9             2.5
# (75 a 79)                         5             1.4
# (80 y más)                        3             0.8
#
# ============================================================
#  MEDELLÍN - GRUPO DE EDAD
# ============================================================
#                            Cantidad  Porcentaje (%)
# Grupo de Edad Quinquenal
# (20 a 24)                        29            14.9
# (25 a 29)                        25            12.9
# (30 a 34)                        23            11.9
# (45 a 49)                        17             8.8
# (55 a 59)                        16             8.2
# (35 a 39)                        16             8.2
# (40 a 44)                        15             7.7
# (18 a 19)                        13             6.7
# (15 a 17)                        10             5.2
# (50 a 54)                         8             4.1
# (60 a 64)                         7             3.6
# (65 a 69)                         6             3.1
# (70 a 74)                         5             2.6
# (80 y más)                        3             1.5
# (10 a 14)                         1             0.5
#
# ============================================================
#  CALI - GRUPO DE EDAD
# ============================================================
#                            Cantidad  Porcentaje (%)
# Grupo de Edad Quinquenal
# (20 a 24)                        17            13.0
# (35 a 39)                        16            12.2
# (25 a 29)                        16            12.2
# (45 a 49)                        14            10.7
# (55 a 59)                        11             8.4
# (30 a 34)                        11             8.4
# (40 a 44)                        10             7.6
# (60 a 64)                         6             4.6
# (80 y más)                        6             4.6
# (15 a 17)                         5             3.8
# (50 a 54)                         5             3.8
# (10 a 14)                         5             3.8
# (18 a 19)                         3             2.3
# (75 a 79)                         3             2.3
# (65 a 69)                         2             1.5
# (70 a 74)                         1             0.8
#
# ============================================================
#  PASTO - GRUPO DE EDAD
# ============================================================
#                            Cantidad  Porcentaje (%)
# Grupo de Edad Quinquenal
# (25 a 29)                        13            25.5
# (20 a 24)                        11            21.6
# (15 a 17)                         7            13.7
# (40 a 44)                         4             7.8
# (35 a 39)                         3             5.9
# (30 a 34)                         3             5.9
# (45 a 49)                         2             3.9
# (65 a 69)                         2             3.9
# (50 a 54)                         2             3.9
# (18 a 19)                         2             3.9
# (80 y más)                        1             2.0
# (10 a 14)                         1             2.0
#
# ============================================================
#  CÚCUTA - GRUPO DE EDAD
# ============================================================
#                            Cantidad  Porcentaje (%)
# Grupo de Edad Quinquenal
# (20 a 24)                         8            16.0
# (30 a 34)                         7            14.0
# (45 a 49)                         6            12.0
# (55 a 59)                         6            12.0
# (40 a 44)                         4             8.0
# (35 a 39)                         4             8.0
# (25 a 29)                         3             6.0
# (50 a 54)                         3             6.0
# (80 y más)                        2             4.0
# (15 a 17)                         2             4.0
# (18 a 19)                         1             2.0
# (75 a 79)                         1             2.0
# (70 a 74)                         1             2.0
# (65 a 69)                         1             2.0
# (60 a 64)                         1             2.0

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Top 5 municipios con más suicidios
top5_municipios = df_suicidios_2024['Municipio del hecho DANE'].value_counts().head(5).index

# Gráfico de edad por municipio
fig, axes = plt.subplots(1, 5, figsize=(20, 6))
fig.suptitle('Distribución de Edad en los 5 Municipios con Más Suicidios', fontsize=16, fontweight='bold')

for i, municipio in enumerate(top5_municipios):
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    edad_stats = datos_mun['Grupo de Edad Quinquenal '].value_counts()

    axes[i].bar(edad_stats.index, edad_stats.values, color='steelblue', edgecolor='black')
    axes[i].set_title(municipio, fontsize=12, fontweight='bold')
    axes[i].set_xlabel('Grupo de Edad')
    axes[i].set_ylabel('Cantidad')
    axes[i].tick_params(axis='x', rotation=45, labelsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.2.Grupo Mayor o Menor de Edad

# %%
for municipio in top_municipios:
    print(f"\n{'='*60}")
    print(f" {municipio} - MAYOR/MENOR DE EDAD")
    print('='*60)
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    grupo_stats = datos_mun['Grupo Mayor Menor de Edad'].value_counts()
    grupo_pct = (grupo_stats / len(datos_mun)) * 100
    grupo_df = pd.DataFrame({'Cantidad': grupo_stats, 'Porcentaje (%)': grupo_pct.round(1)})
    print(grupo_df)
# Out:
# ============================================================
#  BOGOTÁ, D.C. - MAYOR/MENOR DE EDAD
# ============================================================
#                                Cantidad  Porcentaje (%)
# Grupo Mayor Menor de Edad
# b) Mayores de Edad (>18 años)       332            91.5
# a) Menores de Edad (<18 años)        31             8.5
#
# ============================================================
#  MEDELLÍN - MAYOR/MENOR DE EDAD
# ============================================================
#                                Cantidad  Porcentaje (%)
# Grupo Mayor Menor de Edad
# b) Mayores de Edad (>18 años)       183            94.3
# a) Menores de Edad (<18 años)        11             5.7
#
# ============================================================
#  CALI - MAYOR/MENOR DE EDAD
# ============================================================
#                                Cantidad  Porcentaje (%)
# Grupo Mayor Menor de Edad
# b) Mayores de Edad (>18 años)       121            92.4
# a) Menores de Edad (<18 años)        10             7.6
#
# ============================================================
#  PASTO - MAYOR/MENOR DE EDAD
# ============================================================
#                                Cantidad  Porcentaje (%)
# Grupo Mayor Menor de Edad
# b) Mayores de Edad (>18 años)        43            84.3
# a) Menores de Edad (<18 años)         8            15.7
#
# ============================================================
#  CÚCUTA - MAYOR/MENOR DE EDAD
# ============================================================
#                                Cantidad  Porcentaje (%)
# Grupo Mayor Menor de Edad
# b) Mayores de Edad (>18 años)        48            96.0
# a) Menores de Edad (<18 años)         2             4.0

# %%
# Preparar datos
mayor_menor_por_muni = pd.DataFrame()
for municipio in top5_municipios:
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    grupo_stats = datos_mun['Grupo Mayor Menor de Edad'].value_counts()
    mayor_menor_por_muni[municipio] = grupo_stats

mayor_menor_por_muni = mayor_menor_por_muni.fillna(0)

# Gráfico
mayor_menor_por_muni.T.plot(kind='bar', figsize=(10, 6), color=['lightcoral', 'lightblue'], edgecolor='black')
plt.title('Suicidios - Mayor vs Menor de Edad por Municipio', fontsize=14, fontweight='bold')
plt.xlabel('Municipio', fontsize=12)
plt.ylabel('Cantidad de Suicidios', fontsize=12)
plt.legend(title='Grupo')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.3.Sexo de la Víctima

# %%
for municipio in top_municipios:
    print(f"\n{'='*60}")
    print(f" {municipio} - SEXO DE LA VÍCTIMA")
    print('='*60)
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    sexo_stats = datos_mun['Sexo de la victima'].value_counts()
    sexo_pct = (sexo_stats / len(datos_mun)) * 100
    sexo_df = pd.DataFrame({'Cantidad': sexo_stats, 'Porcentaje (%)': sexo_pct.round(1)})
    print(sexo_df)
# Out:
# ============================================================
#  BOGOTÁ, D.C. - SEXO DE LA VÍCTIMA
# ============================================================
#                     Cantidad  Porcentaje (%)
# Sexo de la victima
# Hombre                   281            77.4
# Mujer                     82            22.6
#
# ============================================================
#  MEDELLÍN - SEXO DE LA VÍCTIMA
# ============================================================
#                     Cantidad  Porcentaje (%)
# Sexo de la victima
# Hombre                   152            78.4
# Mujer                     42            21.6
#
# ============================================================
#  CALI - SEXO DE LA VÍCTIMA
# ============================================================
#                     Cantidad  Porcentaje (%)
# Sexo de la victima
# Hombre                   106            80.9
# Mujer                     25            19.1
#
# ============================================================
#  PASTO - SEXO DE LA VÍCTIMA
# ============================================================
#                     Cantidad  Porcentaje (%)
# Sexo de la victima
# Hombre                    32            62.7
# Mujer                     19            37.3
#
# ============================================================
#  CÚCUTA - SEXO DE LA VÍCTIMA
# ============================================================
#                     Cantidad  Porcentaje (%)
# Sexo de la victima
# Hombre                    38            76.0
# Mujer                     12            24.0

# %%
# Preparar datos
sexo_por_muni = pd.DataFrame()
for municipio in top5_municipios:
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    sexo_stats = datos_mun['Sexo de la victima'].value_counts()
    sexo_por_muni[municipio] = sexo_stats

sexo_por_muni = sexo_por_muni.fillna(0)

# Gráfico
sexo_por_muni.T.plot(kind='bar', figsize=(10, 6), color=['lightblue', 'lightcoral'], edgecolor='black')
plt.title('Distribución de Suicidios por Sexo en los 5 Municipios con Más Casos', fontsize=14, fontweight='bold')
plt.xlabel('Municipio', fontsize=12)
plt.ylabel('Cantidad de Suicidios', fontsize=12)
plt.legend(title='Sexo')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  7.4.Estado Civil

# %%
for municipio in top_municipios:
    print(f"\n{'='*60}")
    print(f" {municipio} - ESTADO CIVIL")
    print('='*60)
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    civil_stats = datos_mun['Estado Civil'].value_counts()
    civil_pct = (civil_stats / len(datos_mun)) * 100
    civil_df = pd.DataFrame({'Cantidad': civil_stats, 'Porcentaje (%)': civil_pct.round(1)})
    print(civil_df)
# Out:
# ============================================================
#  BOGOTÁ, D.C. - ESTADO CIVIL
# ============================================================
#                             Cantidad  Porcentaje (%)
# Estado Civil
# Soltero(a)                       222            61.2
# Unión libre                       82            22.6
# Casado(a)                         31             8.5
# Sin información                   11             3.0
# Separado(a), divorciado(a)        11             3.0
# Viudo(a)                           6             1.7
#
# ============================================================
#  MEDELLÍN - ESTADO CIVIL
# ============================================================
#                             Cantidad  Porcentaje (%)
# Estado Civil
# Soltero(a)                       119            61.3
# Casado(a)                         31            16.0
# Unión libre                       30            15.5
# Separado(a), divorciado(a)        10             5.2
# Sin información                    3             1.5
# Viudo(a)                           1             0.5
#
# ============================================================
#  CALI - ESTADO CIVIL
# ============================================================
#                             Cantidad  Porcentaje (%)
# Estado Civil
# Soltero(a)                        66            50.4
# Unión libre                       31            23.7
# Sin información                   14            10.7
# Casado(a)                         13             9.9
# Separado(a), divorciado(a)         4             3.1
# Viudo(a)                           3             2.3
#
# ============================================================
#  PASTO - ESTADO CIVIL
# ============================================================
#                             Cantidad  Porcentaje (%)
# Estado Civil
# Soltero(a)                        33            64.7
# Unión libre                        8            15.7
# Casado(a)                          8            15.7
# Separado(a), divorciado(a)         1             2.0
# Sin información                    1             2.0
#
# ============================================================
#  CÚCUTA - ESTADO CIVIL
# ============================================================
#                             Cantidad  Porcentaje (%)
# Estado Civil
# Soltero(a)                        17            34.0
# Unión libre                       16            32.0
# Casado(a)                          8            16.0
# Sin información                    5            10.0
# Viudo(a)                           2             4.0
# Separado(a), divorciado(a)         2             4.0

# %%
# Top 3 municipios para mejor visualización
top3_municipios = top5_municipios[:3]

fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.suptitle('Estado Civil en los 3 Municipios con Más Suicidios', fontsize=16, fontweight='bold')

for i, municipio in enumerate(top3_municipios):
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    civil_stats = datos_mun['Estado Civil'].value_counts().head(6)

    axes[i].bar(civil_stats.index, civil_stats.values, color='teal', edgecolor='black')
    axes[i].set_title(municipio, fontsize=12, fontweight='bold')
    axes[i].set_xlabel('Estado Civil')
    axes[i].set_ylabel('Cantidad')
    axes[i].tick_params(axis='x', rotation=45, labelsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ###  8.5.País de Nacimiento

# %%
for municipio in top_municipios:
    print(f"\n{'='*60}")
    print(f" {municipio} - PAÍS DE NACIMIENTO")
    print('='*60)
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    pais_stats = datos_mun['País de Nacimiento'].value_counts().head(5)
    pais_pct = (pais_stats / len(datos_mun)) * 100
    pais_df = pd.DataFrame({'Cantidad': pais_stats, 'Porcentaje (%)': pais_pct.round(1)})
    print(pais_df)
# Out:
# ============================================================
#  BOGOTÁ, D.C. - PAÍS DE NACIMIENTO
# ============================================================
#                     Cantidad  Porcentaje (%)
# País de Nacimiento
# Colombia                 351            96.7
# Venezuela                  7             1.9
# España                     1             0.3
# Brasil                     1             0.3
# Filipinas                  1             0.3
#
# ============================================================
#  MEDELLÍN - PAÍS DE NACIMIENTO
# ============================================================
#                     Cantidad  Porcentaje (%)
# País de Nacimiento
# Colombia                 180            92.8
# Venezuela                  8             4.1
# Estados Unidos             2             1.0
# Lituania                   1             0.5
# Alemania                   1             0.5
#
# ============================================================
#  CALI - PAÍS DE NACIMIENTO
# ============================================================
#                     Cantidad  Porcentaje (%)
# País de Nacimiento
# Colombia                 123            93.9
# Venezuela                  6             4.6
# Ecuador                    1             0.8
# España                     1             0.8
#
# ============================================================
#  PASTO - PAÍS DE NACIMIENTO
# ============================================================
#                     Cantidad  Porcentaje (%)
# País de Nacimiento
# Colombia                  49            96.1
# Venezuela                  2             3.9
#
# ============================================================
#  CÚCUTA - PAÍS DE NACIMIENTO
# ============================================================
#                     Cantidad  Porcentaje (%)
# País de Nacimiento
# Colombia                  47            94.0
# Venezuela                  2             4.0
# Sin información            1             2.0

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.suptitle('País de Nacimiento en los 3 Municipios con Más Suicidios', fontsize=16, fontweight='bold')

for i, municipio in enumerate(top3_municipios):
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    pais_stats = datos_mun['País de Nacimiento'].value_counts().head(5)

    axes[i].bar(pais_stats.index, pais_stats.values, color='forestgreen', edgecolor='black')
    axes[i].set_title(municipio, fontsize=12, fontweight='bold')
    axes[i].set_xlabel('País')
    axes[i].set_ylabel('Cantidad')
    axes[i].tick_params(axis='x', rotation=45, labelsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ###  8.6.Escenario del Hecho

# %%
for municipio in top_municipios:
    print(f"\n{'='*60}")
    print(f" {municipio} - ESCENARIO DEL HECHO")
    print('='*60)
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    escenario_stats = datos_mun['Escenario del Hecho'].value_counts().head(5)
    escenario_pct = (escenario_stats / len(datos_mun)) * 100
    escenario_df = pd.DataFrame({'Cantidad': escenario_stats, 'Porcentaje (%)': escenario_pct.round(1)})
    print(escenario_df)
# Out:
# ============================================================
#  BOGOTÁ, D.C. - ESCENARIO DEL HECHO
# ============================================================
#                                                     Cantidad  Porcentaje (%)
# Escenario del Hecho
# Vivienda                                                 279            76.9
# Vía pública                                               25             6.9
# Otros                                                     12             3.3
# Espacios terrestres al aire libre (bosque, potr...        10             2.8
# Sin información                                            8             2.2
#
# ============================================================
#  MEDELLÍN - ESCENARIO DEL HECHO
# ============================================================
#                                                     Cantidad  Porcentaje (%)
# Escenario del Hecho
# Vivienda                                                 155            79.9
# Vía pública                                               16             8.2
# Otros                                                      9             4.6
# Espacios terrestres al aire libre (bosque, potr...         4             2.1
# Terminales de pasajeros                                    2             1.0
#
# ============================================================
#  CALI - ESCENARIO DEL HECHO
# ============================================================
#                                                     Cantidad  Porcentaje (%)
# Escenario del Hecho
# Vivienda                                                  90            68.7
# Sin información                                           12             9.2
# Vía pública                                               10             7.6
# Lugares de hospedaje (hoteles, campamentos y ot...         4             3.1
# Espacios terrestres al aire libre (bosque, potr...         3             2.3
#
# ============================================================
#  PASTO - ESCENARIO DEL HECHO
# ============================================================
#                                                     Cantidad  Porcentaje (%)
# Escenario del Hecho
# Vivienda                                                  43            84.3
# Vía pública                                                2             3.9
# Espacios terrestres al aire libre (bosque, potr...         2             3.9
# Centros de reclusión                                       1             2.0
# Lugares de hospedaje (hoteles, campamentos y ot...         1             2.0
#
# ============================================================
#  CÚCUTA - ESCENARIO DEL HECHO
# ============================================================
#                                                     Cantidad  Porcentaje (%)
# Escenario del Hecho
# Vivienda                                                  42            84.0
# Lugares de hospedaje (hoteles, campamentos y ot...         2             4.0
# Vía pública                                                2             4.0
# Otros                                                      2             4.0
# Centros educativos                                         1             2.0

# %% [markdown]
# ### 8.7.Mecanismo Causal de la Lesión Fatal

# %%
for municipio in top_municipios:
    print(f"\n{'='*60}")
    print(f" {municipio} - MECANISMO CAUSAL")
    print('='*60)
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    mecanismo_stats = datos_mun['Mecanismo Causal de la Lesión Fatal'].value_counts()
    mecanismo_pct = (mecanismo_stats / len(datos_mun)) * 100
    mecanismo_df = pd.DataFrame({'Cantidad': mecanismo_stats, 'Porcentaje (%)': mecanismo_pct.round(1)})
    print(mecanismo_df)
# Out:
# ============================================================
#  BOGOTÁ, D.C. - MECANISMO CAUSAL
# ============================================================
#                                      Cantidad  Porcentaje (%)
# Mecanismo Causal de la Lesión Fatal
# Generadores de asfixia                    258            71.1
# Contundente                                41            11.3
# Tóxico                                     36             9.9
# Proyectil de arma de fuego                 22             6.1
# Cortopunzante                               4             1.1
# Térmico                                     1             0.3
# Cortocontundente                            1             0.3
#
# ============================================================
#  MEDELLÍN - MECANISMO CAUSAL
# ============================================================
#                                      Cantidad  Porcentaje (%)
# Mecanismo Causal de la Lesión Fatal
# Generadores de asfixia                    126            64.9
# Contundente                                36            18.6
# Tóxico                                     17             8.8
# Proyectil de arma de fuego                 11             5.7
# Cortopunzante                               2             1.0
# Cortante                                    1             0.5
# Térmico                                     1             0.5
#
# ============================================================
#  CALI - MECANISMO CAUSAL
# ============================================================
#                                      Cantidad  Porcentaje (%)
# Mecanismo Causal de la Lesión Fatal
# Generadores de asfixia                     93            71.0
# Tóxico                                     18            13.7
# Proyectil de arma de fuego                 11             8.4
# Contundente                                 8             6.1
# Cortopunzante                               1             0.8
#
# ============================================================
#  PASTO - MECANISMO CAUSAL
# ============================================================
#                                      Cantidad  Porcentaje (%)
# Mecanismo Causal de la Lesión Fatal
# Generadores de asfixia                     33            64.7
# Tóxico                                     12            23.5
# Contundente                                 3             5.9
# Proyectil de arma de fuego                  1             2.0
# Cortopunzante                               1             2.0
# Cortante                                    1             2.0
#
# ============================================================
#  CÚCUTA - MECANISMO CAUSAL
# ============================================================
#                                      Cantidad  Porcentaje (%)
# Mecanismo Causal de la Lesión Fatal
# Generadores de asfixia                     34            68.0
# Tóxico                                      6            12.0
# Proyectil de arma de fuego                  5            10.0
# Contundente                                 3             6.0
# Térmico                                     2             4.0

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.suptitle('Escenario del Hecho en los 3 Municipios con Más Suicidios', fontsize=16, fontweight='bold')

for i, municipio in enumerate(top3_municipios):
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    escenario_stats = datos_mun['Escenario del Hecho'].value_counts().head(5)

    axes[i].bar(escenario_stats.index, escenario_stats.values, color='purple', edgecolor='black')
    axes[i].set_title(municipio, fontsize=12, fontweight='bold')
    axes[i].set_xlabel('Escenario')
    axes[i].set_ylabel('Cantidad')
    axes[i].tick_params(axis='x', rotation=45, labelsize=9)

plt.tight_layout()
plt.show()

# %%
# Para los 3 municipios con más datos
top3_municipios = df_suicidios_2024['Municipio del hecho DANE'].value_counts().head(3).index

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Mecanismo Causal de Lesión Fatal - Top 3 Municipios', fontsize=14, fontweight='bold')

for i, municipio in enumerate(top3_municipios):
    datos_mun = df_suicidios_2024[df_suicidios_2024['Municipio del hecho DANE'] == municipio]
    mecanismo_stats = datos_mun['Mecanismo Causal de la Lesión Fatal'].value_counts()

    # Barras horizontales
    axes[i].barh(mecanismo_stats.index, mecanismo_stats.values, color='darkorange', edgecolor='black')
    axes[i].set_title(municipio, fontsize=12, fontweight='bold')
    axes[i].set_xlabel('Cantidad')
    axes[i].invert_yaxis()

    # Agregar valores
    for j, (bar, val) in enumerate(zip(axes[i].containers[0], mecanismo_stats.values)):
        axes[i].text(val + 0.2, j, str(val), va='center', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9.Grafico de dispersion

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# 1. Agrupar delitos por municipio (sumando todas las categorías)
delitos_totales_por_municipio = df_delitos.groupby('MUNICIPIO')['CANTIDAD'].sum().reset_index()
delitos_totales_por_municipio.columns = ['MUNICIPIO', 'TOTAL_DELITOS']

# 2. Unir (merge) los DataFrames de suicidios y delitos por municipio
# Renombramos la columna de municipio en suicidios para que coincida
suicidios_por_municipio = suicidios_por_municipio.rename(columns={'Municipio del hecho DANE': 'MUNICIPIO'})

df_scatter = pd.merge(suicidios_por_municipio, delitos_totales_por_municipio, on='MUNICIPIO', how='inner')

# Ver las primeras filas para asegurarnos
print(df_scatter.head())
# Out:
#    MUNICIPIO  SUICIDIOS  PORCENTAJE  TOTAL_DELITOS
# 0      BELLO         45    1.493033         7662.0
# 1     SOACHA         32    1.061712        13597.0
# 2  FLORENCIA         23    0.763106           25.0
# 3    ARMENIA         22    0.729927           24.0
# 4    PALMIRA         21    0.696749         6902.0

# %%
plt.figure(figsize=(12, 8))

# Crear el scatter plot
plt.scatter(df_scatter['TOTAL_DELITOS'], df_scatter['SUICIDIOS'],
            alpha=0.6, edgecolors='w', linewidth=0.5, s=80)

# Etiquetas y título
plt.xlabel('Total de Delitos por Municipio', fontsize=12)
plt.ylabel('Número de Suicidios', fontsize=12)
plt.title('Relación entre Delitos y Suicidios por Municipio en Colombia (2024)',
          fontsize=14, fontweight='bold')

# Añadir una línea de tendencia (opcional, pero muy útil)
# Calculamos la regresión lineal (usando numpy)
z = np.polyfit(df_scatter['TOTAL_DELITOS'], df_scatter['SUICIDIOS'], 1)
p = np.poly1d(z)
plt.plot(df_scatter['TOTAL_DELITOS'], p(df_scatter['TOTAL_DELITOS']),
         color='red', linestyle='--', linewidth=1.5, label=f'Tendencia (pendiente={z[0]:.4f})')

plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# Opcional: Calcular la correlación
correlacion = df_scatter['TOTAL_DELITOS'].corr(df_scatter['SUICIDIOS'])
print(f"\nCorrelación de Pearson entre delitos totales y suicidios: {correlacion:.4f}")
# Out:
# Correlación de Pearson entre delitos totales y suicidios: 0.7573

# %%
# ==========================================
# 1. CREAR DataFrame CON DELITOS POR CATEGORÍA
# ==========================================

# Agrupar delitos por municipio y categoría
delitos_por_muni_cat = df_delitos.groupby(['MUNICIPIO', 'CATEGORIA'])['CANTIDAD'].sum().reset_index()

# Convertir a formato ancho (cada categoría es una columna)
pivot_delitos = delitos_por_muni_cat.pivot(index='MUNICIPIO', columns='CATEGORIA', values='CANTIDAD').fillna(0)

# Renombrar columnas
pivot_delitos.columns = [f'DELITO_{col.replace(" ", "_")}' for col in pivot_delitos.columns]
pivot_delitos = pivot_delitos.reset_index()

# ==========================================
# 2. UNIR CON SUICIDIOS
# ==========================================

# Calcular suicidios por municipio
suicidios_agg = df_suicidios_2024.groupby('Municipio del hecho DANE').size().reset_index(name='SUICIDIOS')

# Unir
df_scatter = suicidios_agg.merge(pivot_delitos,
                                  left_on='Municipio del hecho DANE',
                                  right_on='MUNICIPIO',
                                  how='inner')

# Calcular total de delitos (opcional)
delitos_cols = [col for col in df_scatter.columns if col.startswith('DELITO_')]
df_scatter['TOTAL_DELITOS'] = df_scatter[delitos_cols].sum(axis=1)

# Ver resultado
print("=== NUEVO df_scatter ===")
print(df_scatter.head())
print("\nColumnas disponibles:", df_scatter.columns.tolist())
# Out:
# === NUEVO df_scatter ===
#   Municipio del hecho DANE  SUICIDIOS  MUNICIPIO  DELITO_Delitos_Sexuales  \
# 0                ABEJORRAL          4  ABEJORRAL                     16.0
# 1                  ACACÍAS          4    ACACÍAS                     77.0
# 2                   ACANDÍ          2     ACANDÍ                      6.0
# 3                  ACEVEDO          2    ACEVEDO                     14.0
# 4                   AGRADO          1     AGRADO                      5.0
#
#    DELITO_Homicidios  DELITO_Hurto  DELITO_Lesiones_Personales  \
# 0               10.0          51.0                        78.0
# 1               21.0         785.0                       639.0
# 2                7.0           3.0                        20.0
# 3               24.0         111.0                        83.0
# 4                6.0          24.0                        50.0
#
#    DELITO_Otros_Delitos  DELITO_Secuestro  TOTAL_DELITOS
# 0                  18.0               0.0          173.0
# 1                 248.0               1.0         1771.0
# 2                   7.0               0.0           43.0
# 3                  71.0               1.0          304.0
# 4                   8.0               0.0           93.0
#
# Columnas disponibles: ['Municipio del hecho DANE', 'SUICIDIOS', 'MUNICIPIO', 'DELITO_Delitos_Sexuales', 'DELITO_Homicidios', 'DELITO_Hurto', 'DELITO_Lesiones_Personales', 'DELITO_Otros_Delitos', 'DELITO_Secuestro', 'TOTAL_DELITOS']

# %% [markdown]
# ## 10.Grafico de dispersion suicidios vs categoria

# %%
import matplotlib.pyplot as plt
import numpy as np

# Obtener columnas de delitos
delitos_cols = [col for col in df_scatter.columns if col.startswith('DELITO_')]
categorias = [col.replace('DELITO_', '').replace('_', ' ') for col in delitos_cols]

n_categorias = len(categorias)
n_cols = 3
n_rows = (n_categorias + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, 6*n_rows))
axes = axes.flatten()

colors = ['steelblue', 'coral', 'forestgreen', 'purple', 'goldenrod', 'darkred']

for i, (delito_col, categoria, color) in enumerate(zip(delitos_cols, categorias, colors)):
    ax = axes[i]
    x = df_scatter[delito_col].values
    y = df_scatter['SUICIDIOS'].values

    ax.scatter(x, y, alpha=0.6, s=60, edgecolors='w', linewidth=0.5, color=color)

    mask = x > 0
    if mask.sum() > 1:
        z = np.polyfit(x[mask], y[mask], 1)
        p = np.poly1d(z)
        x_line = np.linspace(x[mask].min(), x[mask].max(), 100)
        ax.plot(x_line, p(x_line), 'r--', linewidth=2, label=f'Tendencia (pendiente={z[0]:.4f})')

    corr = df_scatter[delito_col].corr(df_scatter['SUICIDIOS'])
    ax.set_xlabel(f'Cantidad de {categoria}', fontsize=11)
    ax.set_ylabel('Número de Suicidios', fontsize=11)
    ax.set_title(f'{categoria} vs Suicidios\nCorrelación: {corr:.4f}', fontsize=12, fontweight='bold')
    ax.legend(loc='upper left', fontsize=9)
    ax.grid(True, linestyle='--', alpha=0.3)

for j in range(i+1, len(axes)):
    axes[j].set_visible(False)

plt.suptitle('Relación entre Diferentes Tipos de Delito y Suicidios por Municipio\nColombia 2024',
             fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##  11.Modelo inicial solo con delitos

# %%
pivot_delitos = df_delitos.pivot_table(
    index='MUNICIPIO',
    columns='CATEGORIA',
    values='CANTIDAD',
    aggfunc='sum',
    fill_value=0
).reset_index()

# %%
suicidios_muni = df_suicidios_2024.groupby(
    'Municipio del hecho DANE'
).size().reset_index(name='suicidios')

# %%
df_modelo = suicidios_muni.merge(
    pivot_delitos,
    left_on='Municipio del hecho DANE',
    right_on='MUNICIPIO',
    how='inner')

# %%
import statsmodels.api as sm

y = df_modelo['suicidios']

X = df_modelo[[
    'Homicidios',
    'Secuestro',
    'Hurto',
    'Delitos Sexuales',
    'Lesiones Personales',
    'Otros Delitos'
]]

X = sm.add_constant(X)

modelo = sm.OLS(y, X).fit()

print(modelo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              suicidios   R-squared:                       0.646
# Model:                            OLS   Adj. R-squared:                  0.643
# Method:                 Least Squares   F-statistic:                     167.3
# Date:                Wed, 20 May 2026   Prob (F-statistic):          1.73e-120
# Time:                        21:04:26   Log-Likelihood:                -1226.3
# No. Observations:                 556   AIC:                             2467.
# Df Residuals:                     549   BIC:                             2497.
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.4318      0.119     12.035      0.000       1.198       1.666
# Homicidios             -0.0010      0.007     -0.148      0.882      -0.014       0.012
# Secuestro               0.3271      0.101      3.252      0.001       0.130       0.525
# Hurto                   0.0025      0.001      3.775      0.000       0.001       0.004
# Delitos Sexuales        0.0772      0.008      9.114      0.000       0.061       0.094
# Lesiones Personales     0.0005      0.001      0.541      0.589      -0.001       0.002
# Otros Delitos          -0.0111      0.002     -4.721      0.000      -0.016      -0.006
# ==============================================================================
# Omnibus:                      506.525   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23887.144
# Skew:                           3.795   Prob(JB):                         0.00
# Kurtosis:                      34.201   Cond. No.                         844.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ##  12.Modelo con variables demoograficas

# %%
sexo_dom = df_suicidios_2024.groupby('Municipio del hecho DANE')['Sexo de la victima'].agg(
    lambda x: x.value_counts().index[0]
).reset_index()

estado_dom = df_suicidios_2024.groupby('Municipio del hecho DANE')['Estado Civil'].agg(
    lambda x: x.value_counts().index[0]
).reset_index()

edad_dom = df_suicidios_2024.groupby('Municipio del hecho DANE')['Grupo Mayor Menor de Edad'].agg(
    lambda x: x.value_counts().index[0]
).reset_index()

escenario_dom = df_suicidios_2024.groupby('Municipio del hecho DANE')['Escenario del Hecho'].agg(
    lambda x: x.value_counts().index[0]
).reset_index()

# %%
df_modelo = suicidios_muni.merge(
    pivot_delitos,
    left_on='Municipio del hecho DANE',
    right_on='MUNICIPIO',
    how='inner'
)

df_modelo = df_modelo.merge(sexo_dom, on='Municipio del hecho DANE', how='left')
df_modelo = df_modelo.merge(estado_dom, on='Municipio del hecho DANE', how='left')
df_modelo = df_modelo.merge(edad_dom, on='Municipio del hecho DANE', how='left')
df_modelo = df_modelo.merge(escenario_dom, on='Municipio del hecho DANE', how='left')

# %%
import statsmodels.formula.api as smf

modelo_final = smf.ols(
'''
suicidios ~

Q("Delitos Sexuales") +
Q("Homicidios") +
Q("Hurto") +
Q("Lesiones Personales") +
Q("Otros Delitos") +
Q("Secuestro")

+

C(Q("Sexo de la victima")) +
C(Q("Estado Civil")) +
C(Q("Grupo Mayor Menor de Edad")) +
C(Q("Escenario del Hecho"))

''',
data=df_modelo
).fit()

print(modelo_final.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              suicidios   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     33.28
# Date:                Wed, 20 May 2026   Prob (F-statistic):          4.24e-105
# Time:                        21:05:58   Log-Likelihood:                -1206.6
# No. Observations:                 556   AIC:                             2479.
# Df Residuals:                     523   BIC:                             2622.
# Df Model:                          32
# Covariance Type:            nonrobust
# ======================================================================================================================================================================================================
#                                                                                                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                                              0.1553      1.645      0.094      0.925      -3.077       3.387
# C(Q("Sexo de la victima"))[T.Mujer]                                                                                                   -0.4330      0.293     -1.476      0.141      -1.009       0.143
# C(Q("Estado Civil"))[T.No aplica]                                                                                                      1.9743      2.248      0.878      0.380      -2.442       6.391
# C(Q("Estado Civil"))[T.Separado(a), divorciado(a)]                                                                                     0.0664      0.659      0.101      0.920      -1.229       1.362
# C(Q("Estado Civil"))[T.Sin información]                                                                                                0.6316      0.384      1.643      0.101      -0.123       1.387
# C(Q("Estado Civil"))[T.Soltero(a)]                                                                                                     1.0182      0.334      3.048      0.002       0.362       1.675
# C(Q("Estado Civil"))[T.Unión libre]                                                                                                    0.1850      0.360      0.514      0.607      -0.522       0.892
# C(Q("Estado Civil"))[T.Viudo(a)]                                                                                                       0.2546      0.831      0.306      0.759      -1.378       1.887
# C(Q("Grupo Mayor Menor de Edad"))[T.b) Mayores de Edad (>18 años)]                                                                     0.9219      0.382      2.412      0.016       0.171       1.673
# C(Q("Escenario del Hecho"))[T.Centros de reclusión]                                                                                    0.2229      1.912      0.117      0.907      -3.534       3.980
# C(Q("Escenario del Hecho"))[T.Espacios acuáticos al aire libre (mar, río, arroyo, humedal, lago, etc.)]                                0.0906      2.707      0.033      0.973      -5.228       5.409
# C(Q("Escenario del Hecho"))[T.Espacios terrestres al aire libre (bosque, potrero, montaña, playa, etc.)]                              -0.7313      1.620     -0.451      0.652      -3.914       2.451
# C(Q("Escenario del Hecho"))[T.Establecimiento comercial (tienda, centro comercial, almacén)]                                          -0.4556      2.696     -0.169      0.866      -5.753       4.841
# C(Q("Escenario del Hecho"))[T.Establecimientos financieros y relacionados (bancos, fiduciarias, etc.)]                                -3.7546      2.712     -1.384      0.167      -9.082       1.573
# C(Q("Escenario del Hecho"))[T.Guarniciones militares y/o de policía]                                                                  -0.9399      1.801     -0.522      0.602      -4.478       2.598
# C(Q("Escenario del Hecho"))[T.Lugar público sin otra indicación]                                                                      -0.2548      2.697     -0.094      0.925      -5.552       5.043
# C(Q("Escenario del Hecho"))[T.Lugares de cuidado de personas (hospicios, orfelinatos, hogares geriátricos, etc.)]                     -0.4742      2.694     -0.176      0.860      -5.766       4.818
# C(Q("Escenario del Hecho"))[T.Lugares de hospedaje (hoteles, campamentos y otros tipos de hospedaje no permanente, moteles, etc.)]    -0.1888      1.908     -0.099      0.921      -3.938       3.560
# C(Q("Escenario del Hecho"))[T.Otros]                                                                                                  -1.0189      1.671     -0.610      0.542      -4.302       2.265
# C(Q("Escenario del Hecho"))[T.Parqueaderos, estacionamientos]                                                                         -0.3804      2.710     -0.140      0.888      -5.705       4.944
# C(Q("Escenario del Hecho"))[T.Sin información]                                                                                        -0.7713      1.664     -0.464      0.643      -4.039       2.497
# C(Q("Escenario del Hecho"))[T.Taller]                                                                                                 -1.7120      2.677     -0.640      0.523      -6.971       3.547
# C(Q("Escenario del Hecho"))[T.Terreno baldío]                                                                                          0.1099      2.205      0.050      0.960      -4.223       4.442
# C(Q("Escenario del Hecho"))[T.Vivienda]                                                                                                0.0809      1.567      0.052      0.959      -2.997       3.159
# C(Q("Escenario del Hecho"))[T.Vía pública]                                                                                            -0.0116      1.652     -0.007      0.994      -3.257       3.234
# C(Q("Escenario del Hecho"))[T.Zonas de actividades agropecuarias]                                                                     -0.4078      1.587     -0.257      0.797      -3.525       2.710
# C(Q("Escenario del Hecho"))[T.Áreas deportivas y/o recreativas]                                                                       -0.7400      2.007     -0.369      0.712      -4.683       3.203
# Q("Delitos Sexuales")                                                                                                                  0.0763      0.008      9.023      0.000       0.060       0.093
# Q("Homicidios")                                                                                                                       -0.0016      0.007     -0.233      0.816      -0.015       0.012
# Q("Hurto")                                                                                                                             0.0022      0.001      3.391      0.001       0.001       0.004
# Q("Lesiones Personales")                                                                                                               0.0005      0.001      0.565      0.572      -0.001       0.002
# Q("Otros Delitos")                                                                                                                    -0.0103      0.002     -4.393      0.000      -0.015      -0.006
# Q("Secuestro")                                                                                                                         0.2784      0.101      2.760      0.006       0.080       0.477
# ==============================================================================
# Omnibus:                      502.951   Durbin-Watson:                   2.157
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23750.615
# Skew:                           3.749   Prob(JB):                         0.00
# Kurtosis:                      34.128   Cond. No.                     4.89e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.89e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## 13.Prueba VIF

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Variables explicativas (SIN SUICIDIOS)
X = df_modelo[['Delitos Sexuales', 'Homicidios', 'Hurto',
               'Lesiones Personales', 'Otros Delitos', 'Secuestro']]

# agregar constante
X = sm.add_constant(X)

# calcular VIF
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i)
              for i in range(X.shape[1])]

print(vif)
# Out:
#               Variable        VIF
# 0                const   1.611561
# 1     Delitos Sexuales   8.593442
# 2           Homicidios   4.328663
# 3                Hurto  10.523059
# 4  Lesiones Personales  11.624235
# 5        Otros Delitos   5.610302
# 6            Secuestro   1.197709

# %% [markdown]
# ## 14.Tes ramsey

# %%
from statsmodels.stats.diagnostic import linear_reset
reset_test = linear_reset(modelo, power=2, use_f=True)

print(reset_test)
# Out:
# <F test: F=0.9587897002187225, p=0.32792407136935364, df_denom=548, df_num=1>

# %% [markdown]
# ##  15.Corregir errores robustos

# %%
df = df_modelo.copy()

# %%
import statsmodels.formula.api as smf
modelo = smf.ols(
    'suicidios ~ Q("Sexo de la victima") + Q("Estado Civil") + Q("Grupo Mayor Menor de Edad") + Q("Escenario del Hecho") + Q("Delitos Sexuales") + Q("Homicidios") + Q("Hurto") + Q("Lesiones Personales") + Q("Otros Delitos") + Q("Secuestro")',
    data=df).fit(cov_type='HC1')   # arregla los errores robustos

# %%
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              suicidios   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     14.35
# Date:                Wed, 20 May 2026   Prob (F-statistic):           1.01e-44
# Time:                        21:06:43   Log-Likelihood:                -1206.6
# No. Observations:                 556   AIC:                             2479.
# Df Residuals:                     523   BIC:                             2622.
# Df Model:                          32
# Covariance Type:                  HC1
# ===================================================================================================================================================================================================
#                                                                                                                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                                           0.1553      0.705      0.220      0.826      -1.226       1.536
# Q("Sexo de la victima")[T.Mujer]                                                                                                   -0.4330      0.210     -2.057      0.040      -0.845      -0.020
# Q("Estado Civil")[T.No aplica]                                                                                                      1.9743      0.332      5.946      0.000       1.323       2.625
# Q("Estado Civil")[T.Separado(a), divorciado(a)]                                                                                     0.0664      0.258      0.257      0.797      -0.440       0.573
# Q("Estado Civil")[T.Sin información]                                                                                                0.6316      0.281      2.247      0.025       0.081       1.182
# Q("Estado Civil")[T.Soltero(a)]                                                                                                     1.0182      0.222      4.586      0.000       0.583       1.453
# Q("Estado Civil")[T.Unión libre]                                                                                                    0.1850      0.189      0.981      0.327      -0.185       0.555
# Q("Estado Civil")[T.Viudo(a)]                                                                                                       0.2546      0.558      0.456      0.648      -0.839       1.349
# Q("Grupo Mayor Menor de Edad")[T.b) Mayores de Edad (>18 años)]                                                                     0.9219      0.249      3.700      0.000       0.434       1.410
# Q("Escenario del Hecho")[T.Centros de reclusión]                                                                                    0.2229      0.727      0.307      0.759      -1.202       1.648
# Q("Escenario del Hecho")[T.Espacios acuáticos al aire libre (mar, río, arroyo, humedal, lago, etc.)]                                0.0906      0.693      0.131      0.896      -1.268       1.449
# Q("Escenario del Hecho")[T.Espacios terrestres al aire libre (bosque, potrero, montaña, playa, etc.)]                              -0.7313      0.666     -1.099      0.272      -2.036       0.573
# Q("Escenario del Hecho")[T.Establecimiento comercial (tienda, centro comercial, almacén)]                                          -0.4556      0.676     -0.674      0.500      -1.781       0.870
# Q("Escenario del Hecho")[T.Establecimientos financieros y relacionados (bancos, fiduciarias, etc.)]                                -3.7546      0.815     -4.604      0.000      -5.353      -2.156
# Q("Escenario del Hecho")[T.Guarniciones militares y/o de policía]                                                                  -0.9399      0.659     -1.426      0.154      -2.231       0.352
# Q("Escenario del Hecho")[T.Lugar público sin otra indicación]                                                                      -0.2548      0.668     -0.381      0.703      -1.564       1.054
# Q("Escenario del Hecho")[T.Lugares de cuidado de personas (hospicios, orfelinatos, hogares geriátricos, etc.)]                     -0.4742      0.673     -0.705      0.481      -1.792       0.844
# Q("Escenario del Hecho")[T.Lugares de hospedaje (hoteles, campamentos y otros tipos de hospedaje no permanente, moteles, etc.)]    -0.1888      0.649     -0.291      0.771      -1.460       1.083
# Q("Escenario del Hecho")[T.Otros]                                                                                                  -1.0189      0.692     -1.472      0.141      -2.375       0.338
# Q("Escenario del Hecho")[T.Parqueaderos, estacionamientos]                                                                         -0.3804      0.727     -0.523      0.601      -1.805       1.044
# Q("Escenario del Hecho")[T.Sin información]                                                                                        -0.7713      0.732     -1.054      0.292      -2.206       0.663
# Q("Escenario del Hecho")[T.Taller]                                                                                                 -1.7120      0.582     -2.941      0.003      -2.853      -0.571
# Q("Escenario del Hecho")[T.Terreno baldío]                                                                                          0.1099      0.872      0.126      0.900      -1.598       1.818
# Q("Escenario del Hecho")[T.Vivienda]                                                                                                0.0809      0.643      0.126      0.900      -1.180       1.342
# Q("Escenario del Hecho")[T.Vía pública]                                                                                            -0.0116      0.705     -0.016      0.987      -1.394       1.371
# Q("Escenario del Hecho")[T.Zonas de actividades agropecuarias]                                                                     -0.4078      0.644     -0.634      0.526      -1.669       0.854
# Q("Escenario del Hecho")[T.Áreas deportivas y/o recreativas]                                                                       -0.7400      0.868     -0.853      0.394      -2.441       0.961
# Q("Delitos Sexuales")                                                                                                               0.0763      0.021      3.565      0.000       0.034       0.118
# Q("Homicidios")                                                                                                                    -0.0016      0.011     -0.148      0.882      -0.023       0.019
# Q("Hurto")                                                                                                                          0.0022      0.001      2.099      0.036       0.000       0.004
# Q("Lesiones Personales")                                                                                                            0.0005      0.002      0.270      0.787      -0.003       0.004
# Q("Otros Delitos")                                                                                                                 -0.0103      0.003     -2.966      0.003      -0.017      -0.004
# Q("Secuestro")                                                                                                                      0.2784      0.126      2.215      0.027       0.032       0.525
# ==============================================================================
# Omnibus:                      502.951   Durbin-Watson:                   2.157
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23750.615
# Skew:                           3.749   Prob(JB):                         0.00
# Kurtosis:                      34.128   Cond. No.                     4.89e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The condition number is large, 4.89e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 32, but rank is 25
#   warnings.warn('covariance of constraints does not have full '

# %% [markdown]
# ##  16.Correguir problemas de Multicolinealidad

# %%
df_modelo['mujer'] = (df_modelo['Sexo de la victima'] == 'Mujer').astype(int)

df_modelo['mayor_edad'] = (df_modelo['Grupo Mayor Menor de Edad'].str.contains('Mayor')).astype(int)

df_modelo['soltero'] = (df_modelo['Estado Civil'] == 'Soltero(a)').astype(int)

df_modelo['escenario_urbano'] = df_modelo['Escenario del Hecho'].isin([
    'Vía pública',
    'Vivienda',
    'Establecimiento comercial (tienda, centro comercial, almacén)'
]).astype(int)

# %% [markdown]
# ##  17.Modelo limpio

# %%
X = df_modelo[[
    'Delitos Sexuales',
    'Homicidios',
    'Hurto',
    'Lesiones Personales',
    'Otros Delitos',
    'Secuestro',
    'mujer',
    'mayor_edad',
    'soltero',
    'escenario_urbano'
]]

X = sm.add_constant(X)

modelo = sm.OLS(df_modelo['suicidios'], X).fit(cov_type='HC1')
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              suicidios   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.659
# Method:                 Least Squares   F-statistic:                     24.85
# Date:                Wed, 20 May 2026   Prob (F-statistic):           8.34e-39
# Time:                        21:07:04   Log-Likelihood:                -1211.3
# No. Observations:                 556   AIC:                             2445.
# Df Residuals:                     545   BIC:                             2492.
# Df Model:                          10
# Covariance Type:                  HC1
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.0279      0.286     -0.098      0.922      -0.588       0.533
# Delitos Sexuales        0.0754      0.020      3.707      0.000       0.036       0.115
# Homicidios             -0.0023      0.010     -0.222      0.824      -0.023       0.018
# Hurto                   0.0024      0.001      2.370      0.018       0.000       0.004
# Lesiones Personales     0.0004      0.002      0.257      0.797      -0.003       0.004
# Otros Delitos          -0.0106      0.003     -3.153      0.002      -0.017      -0.004
# Secuestro               0.2786      0.123      2.274      0.023       0.038       0.519
# mujer                  -0.4586      0.202     -2.273      0.023      -0.854      -0.063
# mayor_edad              0.8232      0.234      3.513      0.000       0.364       1.282
# soltero                 0.7193      0.205      3.510      0.000       0.318       1.121
# escenario_urbano        0.6634      0.166      3.985      0.000       0.337       0.990
# ==============================================================================
# Omnibus:                      497.558   Durbin-Watson:                   2.156
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22222.527
# Skew:                           3.706   Prob(JB):                         0.00
# Kurtosis:                      33.071   Cond. No.                     3.83e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The condition number is large, 3.83e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
