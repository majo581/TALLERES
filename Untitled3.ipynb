# %% [markdown]
# <a href="https://colab.research.google.com/github/majo581/TALLERES/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###  trabajo final
# Maria Jose Gonzalez Serrano

# %%
import json

with open("cuenta-clave.json", "r") as archivo:

    cuentas = json.load(archivo)

print(type(cuentas))
print(cuentas[0])
# Out:
# <class 'list'>
# {'CUENTA': 6710438261, 'CONTRASENA': 8357, 'SALDO': 0}

# %%
 #PUNTO 1

class cajeroelectronico:

    def __init__(self):

        self.intentos = 3
        self.usuario_actual = None


    def iniciar_sesion(self):

        while self.intentos > 0:

            # 1.a pedir cuenta
            cuenta = input("Ingrese su cuenta: ").strip()

            cuenta_encontrada = None


            # buscar cuenta en el JSON
            for usuario in cuentas:

                if str(usuario["CUENTA"]) == cuenta:

                    cuenta_encontrada = usuario
                    break


            # 1.c ver si la cuenta existe
            if cuenta_encontrada is None:

                self.intentos -= 1

                print("No se halló su cuenta")
                print("Le quedan", self.intentos, "intentos")

                continue



            # 1.b pedir contraseña
            clave = input("Ingrese su contraseña: ").strip()



            # 1.d contraseña incorrecta
            if str(cuenta_encontrada["CONTRASENA"]) != clave:

                self.intentos -= 1

                print("Contraseña inválida")
                print("Le quedan", self.intentos, "intentos")

                continue


            # 1.f ingreso exitoso
            print("Ingreso exitoso")

            self.usuario_actual = cuenta_encontrada

            return


        # 1.e gastó los intentos
        print("Gastó todos los intentos")
        print("El programa se cerrará")



cajero = cajeroelectronico()

cajero.iniciar_sesion()



# PUNTO 2

while True:

    print("\n===== MENÚ PRINCIPAL =====")

    print("1. Ver saldo")
    print("2. Retirar dinero")
    print("3. Ahorrar dinero")
    print("4. Salir")

    opcion = input("Seleccione una opción: ")





    # 2.a ver saldo


    if opcion == "1":

        print("Su saldo es:",cajero.usuario_actual["SALDO"])


    # 2.b  retirar

    elif opcion == "2":


        # saldo menor a 10.000
        if cajero.usuario_actual["SALDO"] < 10000:

            print("El saldo es menor a el monto retirable")

            continue

        while True:

            print("\n===== RETIRAR DINERO =====")

            print("1. Retirar 40.000 COP")
            print("2. Retirar 50.000 COP")
            print("3. Retirar 100.000 COP")
            print("4. Retirar otro valor")
            print("5. Salir")


            opcion_retiro = input("Seleccione una opción: ")


            if opcion_retiro == "1":

                monto = 40000


            elif opcion_retiro == "2":

                monto = 50000


            elif opcion_retiro == "3":

                monto = 100000



            # retirar otro valor
            elif opcion_retiro == "4":

                while True:

                    monto = int(input("¿Cuánto quiere retirar?: "))


                    # múltiplos de 10.000
                    if monto % 10000 != 0:

                        print("Solo se permiten múltiplos de 10.000")

                    else:

                        break



            elif opcion_retiro == "5":

                break



            else:

                print("Opción inválida")

                continue




            # fondos insuficientes
            if cajero.usuario_actual["SALDO"] < monto:

                print("No tiene fondos suficientes en la cuenta")

                continue




            # dinero total del cajero
            dinero_cajero = 0

            for billete in billetes:

                dinero_cajero += (billete["DENOMINACION"]* billete["BILLETES"])




            # cajero sin dinero suficiente
            if dinero_cajero < monto:

                print("El cajero no tiene efectivo suficiente")

                continue

            restante = monto


            # combinación de billetes
            for billete in billetes:

                denominacion = billete["DENOMINACION"]

                cantidad = restante // denominacion


                if cantidad > billete["BILLETES"]:

                    cantidad = billete["BILLETES"]


                restante -= (
                    cantidad * denominacion
                )




            # no encontró combinación
            if restante != 0:

                print(
                    "El cajero no tiene el efectivo necesario para darle en este momento"
                )

                continue




            # hacer retiro
            cajero.usuario_actual["SALDO"] -= monto

            restante = monto




            # actualizar billetes
            for billete in billetes:

                denominacion = billete["DENOMINACION"]

                cantidad = restante // denominacion


                if cantidad > billete["BILLETES"]:

                    cantidad = billete["BILLETES"]


                billete["BILLETES"] -= cantidad

                restante -= (cantidad * denominacion3)




            print("Retiro exitoso")

            print("Nuevo saldo:",cajero.usuario_actual["SALDO"])

            break


    # 2.c ahorrar


    elif opcion == "3":


        ahorro = int(input("¿Cuánto quiere ahorrar?: "))


        while True:

            billetes_2000 = int(input("Billetes de 2.000: "))

            billetes_5000 = int(input("Billetes de 5.000: "))

            billetes_10000 = int(input("Billetes de 10.000: "))

            billetes_20000 = int(input("Billetes de 20.000: "))

            billetes_50000 = int( input("Billetes de 50.000: "))

            billetes_100000 = int(input("Billetes de 100.000: "))






            total = (billetes_2000 * 2000 + billetes_5000 * 5000 + billetes_10000 * 10000 + billetes_20000 * 20000 + billetes_50000 * 50000 + billetes_100000 * 100000)




            # 2.c.i combinación insuficiente
            if total < ahorro:

                print("La combinación no cubre el ahorro")

                continue


            # guardar dinero
            cajero.usuario_actual["SALDO"] += ahorro



            # actualizar billetes del cajero
            for billete in billetes:

                if billete["DENOMINACION"] == 10000:

                    billete["BILLETES"] += billetes_10000


                elif billete["DENOMINACION"] == 20000:

                    billete["BILLETES"] += billetes_20000


                elif billete["DENOMINACION"] == 50000:

                    billete["BILLETES"] += billetes_50000



                elif billete["DENOMINACION"] == 100000:

                    billete["BILLETES"] += billetes_100000



            # 2.c.iii excedente
            if total > ahorro:

                excedente = total - ahorro

                print("Se excedió en:",excedente)

                print("1. Donar a caridad")
                print("2. Mandar a otra cuenta")


                opcion_exceso = input("Seleccione una opción: ")




                # donar excedente
                if opcion_exceso == "1":

                    print("Gracias por su solidaridad")



                # mandar a otra cuenta
                elif opcion_exceso == "2":

                    while True:

                        cuenta_destino = input(
                            "Ingrese la cuenta destino: ")

                        encontrada = False



                        for usuario in cuentas:

                            if str(usuario["CUENTA"]) == cuenta_destino:

                                usuario["SALDO"] += excedente

                                encontrada = True

                                break




                        if encontrada:

                            print("Excedente enviado correctamente")

                            break


                        else:

                            print("La cuenta no existe" )




            # 2.c.iv ahorro exitoso
            print("Ahorro exitoso")

            break







    # 2.d salir


    elif opcion == "4":

        print("Usted ha salido de la operación bancaria. Hasta luego.")

        break

    else:

        print("Opción inválida")
# Out:
# Ingrese su cuenta: 6710438261
# Ingrese su contraseña: 8357
# Ingreso exitoso
#
# ===== MENÚ PRINCIPAL =====
# 1. Ver saldo
# 2. Retirar dinero
# 3. Ahorrar dinero
# 4. Salir
# Seleccione una opción: 1
# Su saldo es: 0
#
# ===== MENÚ PRINCIPAL =====
# 1. Ver saldo
# 2. Retirar dinero
# 3. Ahorrar dinero
# 4. Salir
# Seleccione una opción: 3
# ¿Cuánto quiere ahorrar?: 600000
# Billetes de 2.000: 8
# Billetes de 5.000: 0
# Billetes de 10.000: 0
# Billetes de 20.000: 0
# Billetes de 50.000: 0
# Billetes de 100.000: 0
# La combinación no cubre el ahorro
# Billetes de 2.000: 2000
# Billetes de 5.000: 8
# Billetes de 10.000: 9
# Billetes de 20.000: 20
# Billetes de 50.000: 2
# Billetes de 100.000: 2
# Se excedió en: 4230000
# 1. Donar a caridad
# 2. Mandar a otra cuenta
# Seleccione una opción: 1
# Gracias por su solidaridad
# Ahorro exitoso
#
# ===== MENÚ PRINCIPAL =====
# 1. Ver saldo
# 2. Retirar dinero
# 3. Ahorrar dinero
# 4. Salir
# Seleccione una opción: 3
# ...
